# %% [markdown]
# Copyright: Vrije Universiteit Amsterdam, Faculty of Humanities, CLTL

# %% [markdown]
# # Lab 1.2: Querying a REST API

# %% [markdown]
# News articles are a powerful resource to analyze current trends and events. In this Lab, we will extract Dutch news articles from nos.nl.
#
# **Visit https://nos.nl/zoeken/ and have a look at the search utility.**
#
# It provides access to a database. Instead of searching the database in the browser, we can also access it using code through a so-called REST API. REST stands for REpresentational State Transfer and makes it possible to query information from a server.

# %% [markdown]
# ## 1. Querying keywords

# %% [markdown]
# We want to create a dataset that contains articles related to a specific topic. In order to find these articles, we need to determine good keywords for the topic. In this example, we use the keyword "veganisme".
# **Make sure to test several keywords for your topic and inspect the quality of the results.**
#
# Instead of manually copying all search results into files, we want to automate the task. We create a URL by appending the keyword to the search URL of NOS. Note that other websites can use a different syntax. It helps to first test the search interface manually to understand how searches are specified.

# %%
from util_html import *

keyword="veganisme"
url = "https://nos.nl/zoeken/?q=" + keyword

print('The search request URL:', url)

parser_content= url_to_html(url)

# We only select the class search-results from the output. 
print(parser_content.select("ul.search-results"))

# For comparison, print the full output, scroll through it and make sure you find the search results in there. 
print(parser_content)
# Out:
# The search request URL: https://nos.nl/zoeken/?q=veganisme
# [<ul class="search-results">
#                       <li class="search-results__item">
#         <a class="search-results__link" href="/artikel/2309909-ellen-degeneres-krijgt-golden-globe-oeuvreprijs">
#           <div class="search-results__content">
#             <h3 class="search-results__title">Ellen DeGeneres krijgt Golden Globe-oeuvreprijs</h3>
#             <div class="search-results__meta">
#
#               <span class="icon-time icon-space-right"></span>
#
#               <time class="search-results__time" datetime="2019-11-10T22:19:48+0100">
#                 10-11-2019, 22:19
#               </time>
#               <span class="search-results__category">
#                                   in Cultuur &amp; Media                              </span>
#
#
#
#                               <span class="icon-camera icon-red icon-space-left"></span>
#
#             </div>
#                           <div class="search-results__description">
#                 <p>DeGeneres draait al bijna 25 jaar mee in de Amerikaanse televisiewereld. Ze is comédienne, maar vestigt de aandacht regelmatig op maatschappelijke onderwerpen als seksuele geaardheid en veganisme.</p>
#               </div>
#                       </div>
#
#
#   <figure class="search-results__figure">
#
#
#
#
# 				<img alt="" class="search-results__image" src="https://cdn.nos.nl/image/2019/11/10/591977/320x180.jpg"/>
#
#   </figure>
#
#         </a>
#       </li>
#                 <li class="search-results__item">
#         <a class="search-results__link" href="/artikel/2314011-veganistische-moeder-niet-langer-geweerd-van-moedermelkbank">
#           <div class="search-results__content">
#             <h3 class="search-results__title">Veganistische moeder niet langer geweerd van Moedermelkbank</h3>
#             <div class="search-results__meta">
#
#               <span class="icon-time icon-space-right"></span>
#
#               <time class="search-results__time" datetime="2019-12-09T15:29:45+0100">
#                 09-12-2019, 15:29
#               </time>
#               <span class="search-results__category">
#                                   in Binnenland                              </span>
#
#
#
#
#             </div>
#                           <div class="search-results__description">
#                 <p>Wetenschappelijk onderzoek heeft nu aangetoond dat een verantwoord plantaardig dieet resulteert in kwalitatief goede moedermelk.</p>
#               </div>
#                       </div>
#
#
#   <figure class="search-results__figure">
#
#
#
#
# 				<img alt="" class="search-results__image" src="https://cdn.nos.nl/image/2019/12/09/612898/320x180.jpg"/>
#
#   </figure>
#
#         </a>
#       </li>
#                 <li class="search-results__item">
#         <a class="search-results__link" href="/artikel/2382368-toch-geen-strengere-regels-voor-haver-en-sojadrink">
#           <div class="search-results__content">
#             <h3 class="search-results__title">Toch geen strengere regels voor haver- en sojadrink</h3>
#             <div class="search-results__meta">
#
#               <span class="icon-time icon-space-right"></span>
#
#               <time class="search-results__time" datetime="2021-05-26T11:35:07+0200">
#                 26-05-2021, 11:35
#               </time>
#               <span class="search-results__category">
#                                   in Economie                              </span>
#
#
#
#
#             </div>
#                           <div class="search-results__description">
#                 <p>Het Europarlement heeft een voorstel daarover ingetrokken.</p>
#               </div>
#                       </div>
#
#
#   <figure class="search-results__figure">
#
#
#
#
# 				<img alt="" class="search-results__image" src="https://cdn.nos.nl/image/2021/05/26/746370/320x180.jpg"/>
#
#   </figure>
#
#         </a>
#       </li>
#                 <li class="search-results__item">
#         <a class="search-results__link" href="/artikel/2404962-als-je-in-nederland-nog-elke-dag-vlees-eet-dan-ben-je-in-de-minderheid">
#           <div class="search-results__content">
#             <h3 class="search-results__title">'Als je in Nederland nog elke dag vlees eet, dan ben je in de minderheid'</h3>
#             <div class="search-results__meta">
#
#               <span class="icon-time icon-space-right"></span>
#
#               <time class="search-results__time" datetime="2021-11-09T14:25:39+0100">
#                 09-11-2021, 14:25
#               </time>
#               <span class="search-results__category">
#                                   in Economie                              </span>
#
#
#
#                               <span class="icon-camera icon-red icon-space-left"></span>
#
#             </div>
#                           <div class="search-results__description">
#                 <p>Veel mensen zeggen dat ze hun vleesconsumptie proberen te minderen en meer plantaardige alternatieven willen eten.</p>
#               </div>
#                       </div>
#
#
#   <figure class="search-results__figure">
#
#
#
#
# 				<img alt="" class="search-results__image" src="https://cdn.nos.nl/image/2021/11/09/801433/320x180.jpg"/>
#
#   </figure>
#
#         </a>
#       </li>
#                 <li class="search-results__item">
#         <a class="search-results__link" href="/artikel/2247497-veganisten-protesteren-in-amsterdam-tegen-hamburgers-en-bontjassen">
#           <div class="search-results__content">
#             <h3 class="search-results__title">Veganisten protesteren in Amsterdam tegen hamburgers en bontjassen</h3>
#             <div class="search-results__meta">
#
#               <span class="icon-time icon-space-right"></span>
#
#               <time class="search-results__time" datetime="2018-08-25T15:56:43+0200">
#                 25-08-2018, 15:56
#               </time>
#               <span class="search-results__category">
#                                   in Binnenland                              </span>
#
#
#
#                               <span class="icon-camera icon-red icon-space-left"></span>
#
#             </div>
#                           <div class="search-results__description">
#                 <p>Honderden mensen verzamelden zich om aandacht te vragen voor dierenwelzijn.</p>
#               </div>
#                       </div>
#
#
#   <figure class="search-results__figure">
#
#
#
#
# 				<img alt="" class="search-results__image" src="https://cdn.nos.nl/image/2018/08/25/495556/320x180.jpg"/>
#
#   </figure>
#
#         </a>
#       </li>
#                 <li class="search-results__item">
#         <a class="search-results__link" href="/nieuwsuur/artikel/2234918-is-rundvlees-eten-vervuilender-dan-autorijden">
#           <div class="search-results__content">
#             <h3 class="search-results__title">Is rundvlees eten vervuilender dan autorijden?</h3>
#             <div class="search-results__meta">
#
#               <span class="icon-time icon-space-right"></span>
#
#               <time class="search-results__time" datetime="2018-06-03T21:50:25+0200">
#                 03-06-2018, 21:50
#               </time>
#               <span class="search-results__category">
#                                   in Binnenland,                                   in Buitenland                              </span>
#
#                               <span class="icon-play icon-red icon-space-left"></span>
#
#
#
#             </div>
#                           <div class="search-results__description">
#                 <p>Nieuw onderzoek toont aan dat vooral je biefstukje relatief erg vervuilend is. De onderzoekers pleiten voor het veganisme: alle dierlijke producten van het menu geschrapt.</p>
#               </div>
#                       </div>
#
#
#   <figure class="search-results__figure">
#
#
#
#
# 				<img alt="" class="search-results__image" src="https://cdn.nos.nl/image/2017/04/13/369917/320x180.jpg"/>
#
#   </figure>
#
#         </a>
#       </li>
#                 <li class="search-results__item">
#         <a class="search-results__link" href="/artikel/2218583-nepleer-is-nu-ineens-veganistisch">
#           <div class="search-results__content">
#             <h3 class="search-results__title">'Nepleer is nu ineens veganistisch'</h3>
#             <div class="search-results__meta">
#
#               <span class="icon-time icon-space-right"></span>
#
#               <time class="search-results__time" datetime="2018-02-21T11:36:49+0100">
#                 21-02-2018, 11:36
#               </time>
#               <span class="search-results__category">
#                                   in Binnenland                              </span>
#
#
#
#
#             </div>
#                           <div class="search-results__description">
#                 <p>Meer schoenmerken willen zich een diervriendelijk imago aanmeten met schoenen van 'veganistisch leer'. Is dit echt een nieuw materiaal, of proberen winkels makkelijk te scoren?</p>
#               </div>
#                       </div>
#
#
#   <figure class="search-results__figure">
#
#
#
#
# 				<img alt="" class="search-results__image" src="https://cdn.nos.nl/image/2018/02/21/453663/320x180.jpg"/>
#
#   </figure>
#
#         </a>
#       </li>
#                 <li class="search-results__item">
#         <a class="search-results__link" href="/op3/artikel/2220527-waarom-wekt-de-week-zonder-vlees-zo-veel-irritatie-op">
#           <div class="search-results__content">
#             <h3 class="search-results__title">Waarom wekt de Week Zonder Vlees zo veel irritatie op?</h3>
#             <div class="search-results__meta">
#
#               <span class="icon-time icon-space-right"></span>
#
#               <time class="search-results__time" datetime="2018-03-04T08:25:49+0100">
#                 04-03-2018, 08:25
#               </time>
#               <span class="search-results__category">
#                                   in Binnenland                              </span>
#
#
#
#                               <span class="icon-camera icon-red icon-space-left"></span>
#
#             </div>
#                           <div class="search-results__description">
#                 <p>Sommigen laten komende week dat stukje vlees staan tijdens de Week Zonder Vlees. De een vindt het onzin, de ander vindt het noodzaak. Waarom ergeren vleeseters en vegetariërs zich soms aan elkaar?</p>
#               </div>
#                       </div>
#
#
#   <figure class="search-results__figure">
#
#
#
#
# 				<img alt="" class="search-results__image" src="https://cdn.nos.nl/image/2018/03/04/456605/320x180.jpg"/>
#
#   </figure>
#
#         </a>
#       </li>
#                 <li class="search-results__item">
#         <a class="search-results__link" href="/artikel/2208423-mcdonald-s-komt-met-mcvegan-over-15-jaar-zijn-alle-snacks-vega">
#           <div class="search-results__content">
#             <h3 class="search-results__title">McDonald's komt met McVegan: 'Over 15 jaar zijn alle snacks vega'</h3>
#             <div class="search-results__meta">
#
#               <span class="icon-time icon-space-right"></span>
#
#               <time class="search-results__time" datetime="2017-12-19T20:13:58+0100">
#                 19-12-2017, 20:13
#               </time>
#               <span class="search-results__category">
#                                   in Buitenland,                                   in Opmerkelijk                              </span>
#
#
#
#
#             </div>
#                           <div class="search-results__description">
#                 <p>Vanaf 28 december is de McVegan te koop in Zweden en Finland. Dat was te verwachten, zegt duurzame voedselexpert Marco Agema. </p>
#               </div>
#                       </div>
#
#
#   <figure class="search-results__figure">
#
#
#
#
# 				<img alt="" class="search-results__image" src="https://cdn.nos.nl/image/2017/12/19/438998/320x180.jpg"/>
#
#   </figure>
#
#         </a>
#       </li>
#                 <li class="search-results__item">
#         <a class="search-results__link" href="/nieuwsuur/video/2204560-veganisme-is-populair-maar-is-het-ook-gezond">
#           <div class="search-results__content">
#             <h3 class="search-results__title">Veganisme is populair, maar is het ook gezond?</h3>
#             <div class="search-results__meta">
#
#               <span class="icon-time icon-space-right"></span>
#
#               <time class="search-results__time" datetime="2017-11-25T19:06:49+0100">
#                 25-11-2017, 19:06
#               </time>
#               <span class="search-results__category">
#                                   in Binnenland                              </span>
#
#
#
#
#             </div>
#                           <div class="search-results__description">
#                 <p>Veganistische ijswinkels, veganistische producten in de supermarkt, veganistische restaurants. Veganisme is hip.</p>
#               </div>
#                       </div>
#
#
#   <figure class="search-results__figure">
#
#
#
#
# 				<img alt="" class="search-results__image" src="https://cdn.nos.nl/image/2017/11/25/433714/320x180.jpg"/>
#
#   </figure>
#
#         </a>
#       </li>
#                 <li class="search-results__item">
#         <a class="search-results__link" href="/nieuwsuur/artikel/2204524-veganisme-is-populair-maar-is-het-ook-gezond">
#           <div class="search-results__content">
#             <h3 class="search-results__title">Veganisme is populair, maar is het ook gezond?</h3>
#             <div class="search-results__meta">
#
#               <span class="icon-time icon-space-right"></span>
#
#               <time class="search-results__time" datetime="2017-11-25T15:50:09+0100">
#                 25-11-2017, 15:50
#               </time>
#               <span class="search-results__category">
#                                   in Binnenland                              </span>
#
#                               <span class="icon-play icon-red icon-space-left"></span>
#
#
#
#             </div>
#                           <div class="search-results__description">
#                 <p>Vooral in de Randstad eten mensen meer en meer plantaardige producten. Want veganisme is hip en lijkt een succes als nieuwe levensstijl. Maar doet een veganist zichzelf niet tekort?</p>
#               </div>
#                       </div>
#
#
#   <figure class="search-results__figure">
#
#
#
#
# 				<img alt="" class="search-results__image" src="https://cdn.nos.nl/image/2017/11/25/433641/320x180.jpg"/>
#
#   </figure>
#
#         </a>
#       </li>
#                 <li class="search-results__item">
#         <a class="search-results__link" href="/op3/artikel/2128277-veganisme-is-booming-business-in-israel">
#           <div class="search-results__content">
#             <h3 class="search-results__title">Veganisme is booming business  in Israël</h3>
#             <div class="search-results__meta">
#
#               <span class="icon-time icon-space-right"></span>
#
#               <time class="search-results__time" datetime="2016-08-26T14:04:59+0200">
#                 26-08-2016, 14:04
#               </time>
#               <span class="search-results__category">
#                                   in Buitenland                              </span>
#
#
#
#                               <span class="icon-camera icon-red icon-space-left"></span>
#
#             </div>
#                           <div class="search-results__description">
#                 <p>In Israël is de markt voor veganistische producten groot. Daardoor is er veel ruimte voor innovatie. Sinds kort kent het land bijvoorbeeld een veganistische chocoladefabriek.</p>
#               </div>
#                       </div>
#
#
#   <figure class="search-results__figure">
#
#
#
#
# 				<img alt="" class="search-results__image" src="https://cdn.nos.nl/image/2016/08/26/312204/320x180.jpg"/>
#
#   </figure>
#
#         </a>
#       </li>
#                 <li class="search-results__item">
#         <a class="search-results__link" href="/op3/artikel/2121930-veganburger-van-80-miljoen-smaakt-naar-vlees">
#           <div class="search-results__content">
#             <h3 class="search-results__title">Veganburger van 80 miljoen smaakt naar vlees</h3>
#             <div class="search-results__meta">
#
#               <span class="icon-time icon-space-right"></span>
#
#               <time class="search-results__time" datetime="2016-07-29T18:10:57+0200">
#                 29-07-2016, 18:10
#               </time>
#               <span class="search-results__category">
#                                   in Buitenland                              </span>
#
#
#
#
#             </div>
#                           <div class="search-results__description">
#                 <p>125 wetenschappers en 80 miljoen dollar hebben naar eigen zeggen de perfecte veganistische hamburger opgeleverd.</p>
#               </div>
#                       </div>
#
#
#   <figure class="search-results__figure">
#
#
#
#
# 				<img alt="" class="search-results__image" src="https://cdn.nos.nl/image/2016/07/29/303689/320x180.jpg"/>
#
#   </figure>
#
#         </a>
#       </li>
#                 <li class="search-results__item">
#         <a class="search-results__link" href="/artikel/2099574-discussierende-demonstranten-en-politie-botsen-in-parijs">
#           <div class="search-results__content">
#             <h3 class="search-results__title">Discussiërende demonstranten en politie botsen in Parijs</h3>
#             <div class="search-results__meta">
#
#               <span class="icon-time icon-space-right"></span>
#
#               <time class="search-results__time" datetime="2016-04-16T16:46:22+0200">
#                 16-04-2016, 16:46
#               </time>
#               <span class="search-results__category">
#                                   in Buitenland                              </span>
#
#                               <span class="icon-play icon-red icon-space-left"></span>
#
#
#
#             </div>
#                           <div class="search-results__description">
#                 <p>Al meer dan twee weken wordt in Parijs gediscussieerd en gedemonstreerd tegen sociale ongelijkheid. Vannacht liep het uit de hand.</p>
#               </div>
#                       </div>
#
#
#   <figure class="search-results__figure">
#
#
#
#
# 				<img alt="" class="search-results__image" src="https://cdn.nos.nl/image/2016/04/16/274396/320x180.jpg"/>
#
#   </figure>
#
#         </a>
#       </li>
#                 <li class="search-results__item">
#         <a class="search-results__link" href="/op3/artikel/2090859-gaat-het-nieuwe-vlees-het-oude-vlees-verslaan">
#           <div class="search-results__content">
#             <h3 class="search-results__title">Gaat het nieuwe vlees het oude vlees verslaan?</h3>
#             <div class="search-results__meta">
#
#               <span class="icon-time icon-space-right"></span>
#
#               <time class="search-results__time" datetime="2016-03-05T16:46:24+0100">
#                 05-03-2016, 16:46
#               </time>
#               <span class="search-results__category">
#                                   in Binnenland                              </span>
#
#
#
#                               <span class="icon-camera icon-red icon-space-left"></span>
#
#             </div>
#                           <div class="search-results__description">
#                 <p>Dit weekend staat de veganistenbeurs VeggieWorld voor het eerst in Nederland, in de Jaarbeurs in Utrecht. En daar is het druk.</p>
#               </div>
#                       </div>
#
#
#   <figure class="search-results__figure">
#
#
#
#
# 				<img alt="" class="search-results__image" src="https://cdn.nos.nl/image/2016/03/05/262111/320x180.jpg"/>
#
#   </figure>
#
#         </a>
#       </li>
#
#         </ul>]
# <!DOCTYPE html>
# <!--[if IE 8]>    <html class="no-js lt-ie10 lt-ie9" lang="nl">               <![endif]--><!--[if (gt IE 8) & (!IEMobile)]>  <html class="no-js lt-ie10 ie9-desktop" lang="nl"> <![endif]--><!--[if (gt IE 8) & (IEMobile)]>   <html class="no-js lt-ie10 ie9-mobile" lang="nl"> <![endif]--><!--[if !IE]><!--><html class="no-js" lang="nl"><!--<![endif]--><head>
#
#               <meta charset="utf-8"/>
#       <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#       <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#
#         <title>
#         NOS Zoeken
#     </title>
#
#
#                     <link href="https://cdn.nos.nl/assets/nos-symfony/be48190/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#       <link href="https://cdn.nos.nl/assets/nos-symfony/be48190/android-icon.png" rel="icon" sizes="192x192"/>
#       <link href="https://cdn.nos.nl/assets/nos-symfony/be48190/apple-touch-icon.png" rel="apple-touch-icon"/>
#
#               <meta content="NOS" name="app-name"/>
#     <meta content="app-id=516491461" name="apple-itunes-app"/>
#     <meta content="app-id=nl.nos.app" name="google-play-app"/>
#
#
#
#           <meta content="noindex, follow" name="robots"/>
#
#                 <link href="https://fonts.googleapis.com/css?family=Roboto+Condensed:700" rel="stylesheet"/>
#             <link href="https://cdn.nos.nl/assets/nos-symfony/be48190/bundles/nossite/css/styles.css" media="all" rel="stylesheet" type="text/css"/>
#       <link href="https://component-renderer.api.nos.nl/components.client.nos.1dc056f2750d1b594333.css" media="all" rel="stylesheet" type="text/css"/>
#
#
#
#           <script src="https://cdn.nos.nl/assets/nos-symfony/be48190/js/lib/modernizr/modernizr.min.js"></script>
#
#               <script type="text/javascript">
#           var _sf_async_config = _sf_async_config || {};
#           _sf_async_config.uid = 64919;
#           _sf_async_config.domain = window.location.hostname; // DOMAIN
#           _sf_async_config.flickerControl = false;
#           _sf_async_config.articleBlockSelector = 'li.cb-mab'; // this class is set in the component renderer
#           _sf_async_config.useCanonical = true;
#           var _sf_startpt = (new Date()).getTime();
#       </script>
#       <script async="" src="//static.chartbeat.com/js/chartbeat_mab_image.js"></script>
#
#           <!--[if lt IE 9]>
#         <script src="https://cdn.nos.nl/assets/nos-symfony/be48190js/lib/vendor/respond/respond.1.1.0.min.js"></script>
#       <![endif]-->
#
#     <script src="https://polyfill.io/v3/polyfill.min.js?features=CustomEvent%2Object.assign%2CArray.prototype.find%2CArray.prototype.findIndex%2CIntersectionObserver"></script>
# </head>
#
#   <body class="page-search" data-comscore='{"name":"track.click.search"}'>
# <script>
#   window.instancesContainer = {
#     instances: {},
#     registerInstance: function(name, instance, options) {
#       window.instancesContainer.instances[name] = {};
#       window.instancesContainer.instances[name].loader = new Promise(function (resolve, reject) {
#         var inst = new instance(options);
#         window.instancesContainer.instances[name].instance = inst;
#         inst.init().then(function() {
#           resolve(inst);
#         })
#       });
#
#       window.instancesContainer.setupRegistryEvent(name);
#
#       return window.instancesContainer.instances[name].loader;
#     },
#     getInstance: function(name) {
#         return new Promise(function (resolve, reject) {
#           return window.instancesContainer.instances[name].loader
#             .then(function() {
#               resolve(window.instancesContainer.instances[name].instance)
#             })
#             .catch(function() {
#               reject('Could not get instance', error)
#             })
#         });
#     },
#     setupRegistryEvent: function(name) {
#       var event = undefined;
#       if (typeof(Event) === 'function') {
#           event = new Event(name + '_loading');
#       } else {
#           event = document.createEvent('Event');
#           event.initEvent(name + '_loading', true, true);
#       }
#
#       window.dispatchEvent(event);
#     },
#   }
# </script>
#
#       <div data-vue="app-banner"></div>
#     <header class="nav-wrapper" id="nav">
#
#
#
#   <div data-ssr-id="805eb640-6369-11ed-871e-e75df0052348" data-ssr-name="components/nos/_global/Navigation/Navigation"><header class="bar_28Na2J9H" data-server-rendered="true"><ol class="list_1fzP3zJH"><li><a class="link_2o2aI7eT" href="#menu">Ga naar het menu</a></li> <li><a class="link_2o2aI7eT" href="#content">Ga naar de inhoud</a></li></ol> <div class="container_JyDByhf6 hideOnMobile_3P2O5Vch"><nav class="navigation_12wQxGO0"><ol class="menu_15PH6fX8" id="menu"><li class="listItem_18e2jsEJ"><a class="logoLink_1c-S9666" href="/"><svg class="nosLogo_2fQkVIuQ" height="28" viewBox="0 0 79 28" width="79" xmlns="http://www.w3.org/2000/svg"><g fill="none" fill-rule="evenodd"><path d="M78.94 18.93c0-5.31-2.57-6.91-9.32-8.54-3.46-.8-4.41-1.27-4.41-2.28 0-.96.53-1.66 2.76-1.66 2.72 0 5.1.93 7.48 2.55 0 0 3.15-5.01 3.49-5.87C76.2 1.12 72.92 0 68.35 0c-6.48 0-10.58 3.44-10.58 8.54 0 5.4 3.1 7.19 9.58 8.7 3.6.84 4.57 1.46 4.57 2.47 0 1.27-.85 1.74-3.5 1.74-2.49 0-5.9-1.36-7.85-2.71l-3.6 5.87a21.29 21.29 0 0011.3 3.29c6.45 0 10.67-2.33 10.67-8.73" fill="#949494"></path> <path d="M27 13.95C27 6.25 33.32 0 41.12 0c7.8 0 14.13 6.25 14.13 13.95S48.92 27.9 41.12 27.9C33.32 27.9 27 21.65 27 13.95m7.2 0c0-3.78 3.1-6.84 6.92-6.84 3.83 0 6.93 3.06 6.93 6.84s-3.1 6.84-6.93 6.84a6.89 6.89 0 01-6.93-6.84" fill="#E61E14"></path> <path d="M23.67 27.9V0h-7.33v14.35S6.88 0 6.82 0H.36v27.9h7.32V13.55l9.63 14.35h6.36z" fill="#949494"></path></g></svg></a></li> <li aria-haspopup="true" class="listItem_2fZxURrd"><a class="anchor_3RuvwRy5" href="/" title="Nieuws">
#         Nieuws
#         <svg class="chevron_3NMjkcVr" viewBox="0 0 9 6" xmlns="http://www.w3.org/2000/svg"><path d="M4.1789 4.8654a.4507.4507 0 00.6057.0335l.037-.0335 3.0453-3.0806a.4635.4635 0 000-.6502.4507.4507 0 00-.6058-.0335l-.0369.0335-2.7244 2.7556-2.724-2.7556a.4507.4507 0 00-.6058-.0335l-.037.0336a.4637.4637 0 00-.033.6128l.0331.0373L4.179 4.8654z" fill="currentColor" fill-rule="nonzero"></path></svg></a> <!----></li> <li aria-haspopup="true" class="listItem_2fZxURrd"><a class="anchor_3RuvwRy5" href="/sport" title="Sport">
#         Sport
#         <svg class="chevron_3NMjkcVr" viewBox="0 0 9 6" xmlns="http://www.w3.org/2000/svg"><path d="M4.1789 4.8654a.4507.4507 0 00.6057.0335l.037-.0335 3.0453-3.0806a.4635.4635 0 000-.6502.4507.4507 0 00-.6058-.0335l-.0369.0335-2.7244 2.7556-2.724-2.7556a.4507.4507 0 00-.6058-.0335l-.037.0336a.4637.4637 0 00-.033.6128l.0331.0373L4.179 4.8654z" fill="currentColor" fill-rule="nonzero"></path></svg></a> <!----></li> <li aria-haspopup="true" class="listItem_2fZxURrd"><a class="anchor_3RuvwRy5" href="/uitzendingen">
#         Uitzendingen
#       </a> <!----></li></ol></nav> <nav class="navigation_12wQxGO0"><ol class="subMenu_aXWsrISZ"><li class="listItem_18e2jsEJ"><a class="anchor_2WjlocAx" href="/weer" title="Weer"><svg class="weatherIcon_225J9Lf7" height="18" title="Weer" viewBox="0 0 24 18" width="24" xmlns="http://www.w3.org/2000/svg"><g fill="currentColor" fill-rule="nonzero"><path d="M24 14.52c0 1.8-1.45 3.25-3.25 3.25-.57 0-2 0-5.94.03l-5.95.04A3.25 3.25 0 018 11.47 3.25 3.25 0 0112 8.54a5.07 5.07 0 019.7 2.87c1.33.4 2.3 1.65 2.3 3.11zm-3.28-1.74a.75.75 0 01-.7-1.04 3.57 3.57 0 10-6.8-2.05c-.1.5-.67.76-1.11.5a1.72 1.72 0 00-.88-.24 1.75 1.75 0 00-1.72 2.03.75.75 0 01-.7.87 1.74 1.74 0 00.05 3.49l5.94-.04 5.95-.03a1.75 1.75 0 00.03-3.5h-.06zM11.32 5.37a.75.75 0 11-.72 1.31 2.86 2.86 0 00-4.07 3.5.75.75 0 11-1.41.5 4.37 4.37 0 016.2-5.31zm-1.38-3a.75.75 0 11-1.5 0V.75a.75.75 0 011.5 0v1.62zM.75 9.94a.75.75 0 010-1.5h1.62a.75.75 0 110 1.5H.75zm1.94-6.19A.75.75 0 113.75 2.7L4.9 3.84a.75.75 0 01-1.07 1.05L2.7 3.75z"></path></g></svg></a></li> <li class="listItem_18e2jsEJ"><a class="anchor_2WjlocAx" href="/zoeken" title="Zoeken"><svg height="24" viewBox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M10.04 0a10.04 10.04 0 017.7 16.47l6 6a.9.9 0 01-1.2 1.33l-.08-.06-5.99-5.99A10.04 10.04 0 1110.04 0zm0 1.8a8.24 8.24 0 100 16.48 8.24 8.24 0 000-16.48z" fill="currentColor" fill-rule="nonzero"></path></svg></a></li> <li class="listItem_18e2jsEJ"><a class="logoLink_1c-S9666" href="https://www.npostart.nl/?ns_campaign=meernpo&amp;ns_mchannel=omroep&amp;ns_source=nos&amp;ns_linkname=button" target="_blank" title="NPO Start"><svg class="npoStartLogo_1u5wIZGE" height="35" viewBox="0 0 50 35" width="50" xmlns="http://www.w3.org/2000/svg"><g fill="none" fill-rule="nonzero"><path d="M32.1 20.02L19.24 32.88c-1.3 1.3-2.78 1.3-4.08 0L2.3 20.03c-1.29-1.3-1.29-2.78 0-4.08L15.16 3.1c1.3-1.3 2.78-1.3 4.08 0L32.1 15.95c1.3 1.3 1.3 2.78 0 4.08z" fill="#D7D8D6"></path> <path d="M13.79 12.33l-.94-.94c-.4-.4-.76-.38-1.2.06l-.82.82c-.44.43-.45.8-.06 1.19l.94.94c.4.39.76.38 1.2-.06l.81-.82c.44-.44.45-.8.07-1.2zm1.02-1c.97.97.99 2.14-.1 3.22l-.83.83a1.6 1.6 0 01-.72.47l.72.72c.37.36.32.76.04 1.04s-.68.33-1.05-.03l-3.13-3.13c-.96-.97-.98-2.13.1-3.21l.78-.78c1.09-1.09 2.25-1.07 3.22-.1l.97.97zm3.87-3.9l-.94-.93c-.4-.4-.76-.38-1.2.06l-.82.82c-.43.43-.45.8-.06 1.19l.94.94c.4.39.76.38 1.2-.06l.82-.82c.43-.44.45-.8.06-1.2zm1.02-.99c.97.97.99 2.14-.1 3.22l-.77.78c-1.09 1.08-2.25 1.07-3.22.1l-.98-.98c-.96-.97-.98-2.13.1-3.22l.78-.77c1.09-1.09 2.25-1.07 3.22-.1l.97.97zm-8.77 10.97c.36.36.31.77.03 1.05-.28.27-.68.32-1.04-.04l-2.05-2.05c-.4-.4-.76-.38-1.2.06l-.82.82c-.43.43-.45.8-.06 1.19l2.06 2.05c.36.36.31.77.03 1.05-.27.27-.68.33-1.04-.03l-2.07-2.08c-.97-.97-.99-2.13.1-3.22l.77-.77c1.09-1.09 2.25-1.07 3.22-.1l2.07 2.07zm7-1.46c-1.29 1.3-1.29 2.78 0 4.08L30.8 32.88c1.3 1.3 2.78 1.3 4.07 0l12.86-12.86c1.3-1.29 1.3-2.78 0-4.07L34.87 3.09c-1.3-1.3-2.78-1.3-4.07 0L17.94 15.95" fill="#FF6D00"></path> <path d="M24.48 17.36c-.6-.15-.8-.2-.8-.47 0-.36.52-.41.83-.41.27 0 .63.06.93.17.08.02.16.05.24.05.22 0 .32-.17.39-.33l.05-.12a.7.7 0 00.05-.23c0-.18-.12-.32-.32-.4a3.8 3.8 0 00-1.32-.21c-1.33 0-2.09.56-2.09 1.55 0 1.1.91 1.3 1.87 1.51h.02c.53.12.79.2.79.48 0 .1 0 .43-.89.43-.35 0-.72-.07-1.12-.21a.76.76 0 00-.24-.05c-.22 0-.32.16-.39.33l-.05.13a.64.64 0 00-.06.23c0 .18.12.33.32.4.4.16.91.24 1.53.24 1.38 0 2.14-.56 2.14-1.56 0-1.1-.91-1.31-1.88-1.53zm10.58.22l-3.18-2a.4.4 0 00-.62.34v4c0 .3.35.5.62.33l3.18-2a.4.4 0 000-.67zM30.4 19.6c-.04-.2-.15-.3-.34-.3l-.18.02a2 2 0 01-.24.02c-.5 0-.8-.15-.8-.91v-1.85h1.1c.32 0 .47-.16.47-.48v-.13c0-.33-.15-.48-.48-.48h-1.08v-.7c0-.32-.16-.48-.48-.48h-.3c-.33 0-.48.16-.48.48v.7h-.28c-.32 0-.48.15-.48.48v.13c0 .32.16.48.48.48h.28v1.96c0 1.28.61 1.9 1.88 1.9.24 0 .47-.04.64-.07.23-.04.36-.18.36-.4l-.03-.2-.04-.17zm12.64.18L43 19.6c-.04-.2-.15-.3-.34-.3l-.18.02-.25.02c-.48 0-.78-.15-.78-.91v-1.85h1.08c.33 0 .48-.16.48-.48v-.13c0-.33-.15-.48-.48-.48h-1. ...
#         Nieuws
#         <svg class="chevron_3YFhNvQ2" viewBox="0 0 9 6" xmlns="http://www.w3.org/2000/svg"><path d="M4.1789 4.8654a.4507.4507 0 00.6057.0335l.037-.0335 3.0453-3.0806a.4635.4635 0 000-.6502.4507.4507 0 00-.6058-.0335l-.0369.0335-2.7244 2.7556-2.724-2.7556a.4507.4507 0 00-.6058-.0335l-.037.0336a.4637.4637 0 00-.033.6128l.0331.0373L4.179 4.8654z" fill="currentColor" fill-rule="nonzero"></path></svg></button> <!----></li> <li aria-haspopup="true" class="listItem_2fZxURrd"><button aria-label="Nieuws" class="anchor_3RuvwRy5" title="Nieuws">
#         Sport
#         <svg class="chevron_3YFhNvQ2" viewBox="0 0 9 6" xmlns="http://www.w3.org/2000/svg"><path d="M4.1789 4.8654a.4507.4507 0 00.6057.0335l.037-.0335 3.0453-3.0806a.4635.4635 0 000-.6502.4507.4507 0 00-.6058-.0335l-.0369.0335-2.7244 2.7556-2.724-2.7556a.4507.4507 0 00-.6058-.0335l-.037.0336a.4637.4637 0 00-.033.6128l.0331.0373L4.179 4.8654z" fill="currentColor" fill-rule="nonzero"></path></svg></button> <!----></li></ol></nav> <nav class="navigation_u2mVGOq2"><ol class="menu_1lRMHJ2K"><li aria-haspopup="true" class="listItem_2fZxURrd"><button class="anchor_3RuvwRy5"><svg class="moreIcon_1oX7Dcl1" height="24" viewBox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M3.13 8.87a3.13 3.13 0 110 6.26 3.13 3.13 0 010-6.26zm8.87 0a3.13 3.13 0 110 6.26 3.13 3.13 0 010-6.26zm8.87 0a3.13 3.13 0 110 6.26 3.13 3.13 0 010-6.26zm-17.74 1.8a1.33 1.33 0 100 2.66 1.33 1.33 0 000-2.66zm8.87 0a1.33 1.33 0 100 2.66 1.33 1.33 0 000-2.66zm8.87 0a1.33 1.33 0 100 2.66 1.33 1.33 0 000-2.66z" fill="currentColor" fill-rule="nonzero"></path></svg></button> <!----></li> <li class="listItem_mASJsHfT hasDivider_2rLiI72n"><a class="anchor_SrTzS95-" href="/zoeken" title="Zoeken"><svg class="iconStyle_1-eH3gt0" height="24" viewBox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M10.04 0a10.04 10.04 0 017.7 16.47l6 6a.9.9 0 01-1.2 1.33l-.08-.06-5.99-5.99A10.04 10.04 0 1110.04 0zm0 1.8a8.24 8.24 0 100 16.48 8.24 8.24 0 000-16.48z" fill="currentColor" fill-rule="nonzero"></path></svg></a></li></ol></nav></div></header></div>
# <script data-ssr-id="805eb640-6369-11ed-871e-e75df0052348" data-ssr-name="components/nos/_global/Navigation/Navigation" type="application/json">{"pathInfo":"/zoeken"}</script>
#
#   	</header>
#
#         	<main id="content">
#
#   <div id="wrapper">
#
#     <div id="search-wrapper">
#
# <form action="/zoeken" class="search-form" method="get">
#   <fieldset>
#     <input autofocus="" class="search-form__input js-search-form-input" name="q" placeholder="veganisme" title="Zoeken" type="search" value="veganisme"/>
#     <button class="search-form__submit" type="submit">
#       <span class="icon-search search-form__icon"></span>
#       <span class="search-form__submit__text">Zoeken</span>
#     </button>
#   </fieldset>
# </form>
#     </div>
#
#     <div id="column-aside">
#
#   <nav class="nav-aside padded-small">
#     <ul class="nav-aside_sub">
#
#               <li class="nav-aside__item nav-aside__item--active">
#           <a class="nav-aside__link" href="/zoeken?q=veganisme">Volledige periode</a>
#
#           <ul>
#                                         <li class="nav-aside__subitem">
#                 <a class="nav-aside__link nav-aside__link--sub" href="/zoeken?q=veganisme&amp;date=2022-11-13" title="">Vandaag</a>
#               </li>
#                                         <li class="nav-aside__subitem">
#                 <a class="nav-aside__link nav-aside__link--sub" href="/zoeken?q=veganisme&amp;date=2022-11-06" title="">Afgelopen week</a>
#               </li>
#                                         <li class="nav-aside__subitem">
#                 <a class="nav-aside__link nav-aside__link--sub" href="/zoeken?q=veganisme&amp;date=2022-10-14" title="">Afgelopen maand</a>
#               </li>
#                                         <li class="nav-aside__subitem">
#                 <a class="nav-aside__link nav-aside__link--sub" href="/zoeken?q=veganisme&amp;date=2021-11-13" title="">Afgelopen jaar</a>
#               </li>
#                       </ul>
#
#         </li>
#
#     </ul>
#   </nav>
#
#   <div class="search-dropdown">
#     <div class="search-dropdown__container">
#
#               <select class="search-dropdown__select js-option">
#             <option class="search-dropdown__option" selected="" value="/zoeken?q=veganisme">Volledige periode</option>
#
#                                         <option class="search-dropdown__option" value="/zoeken?q=veganisme&amp;date=2022-11-13">Vandaag</option>
#                                         <option class="search-dropdown__option" value="/zoeken?q=veganisme&amp;date=2022-11-06">Afgelopen week</option>
#                                         <option class="search-dropdown__option" value="/zoeken?q=veganisme&amp;date=2022-10-14">Afgelopen maand</option>
#                                         <option class="search-dropdown__option" value="/zoeken?q=veganisme&amp;date=2021-11-13">Afgelopen jaar</option>
#
#         </select>
#
#     </div>
#   </div>
#     </div>
#
#     <div id="column-main">
#       <ul class="search-results">
#                       <li class="search-results__item">
#         <a class="search-results__link" href="/artikel/2309909-ellen-degeneres-krijgt-golden-globe-oeuvreprijs">
#           <div class="search-results__content">
#             <h3 class="search-results__title">Ellen DeGeneres krijgt Golden Globe-oeuvreprijs</h3>
#             <div class="search-results__meta">
#
#               <span class="icon-time icon-space-right"></span>
#
#               <time class="search-results__time" datetime="2019-11-10T22:19:48+0100">
#                 10-11-2019, 22:19
#               </time>
#               <span class="search-results__category">
#                                   in Cultuur &amp; Media                              </span>
#
#
#
#                               <span class="icon-camera icon-red icon-space-left"></span>
#
#             </div>
#                           <div class="search-results__description">
#                 <p>DeGeneres draait al bijna 25 jaar mee in de Amerikaanse televisiewereld. Ze is comédienne, maar vestigt de aandacht regelmatig op maatschappelijke onderwerpen als seksuele geaardheid en veganisme.</p>
#               </div>
#                       </div>
#
#
#   <figure class="search-results__figure">
#
#
#
#
# 				<img alt="" class="search-results__image" src="https://cdn.nos.nl/image/2019/11/10/591977/320x180.jpg"/>
#
#   </figure>
#
#         </a>
#       </li>
#                 <li class="search-results__item">
#         <a class="search-results__link" href="/artikel/2314011-veganistische-moeder-niet-langer-geweerd-van-moedermelkbank">
#           <div class="search-results__content">
#             <h3 class="search-results__title">Veganistische moeder niet langer geweerd van Moedermelkbank</h3>
#             <div class="search-results__meta">
#
#               <span class="icon-time icon-space-right"></span>
#
#               <time class="search-results__time" datetime="2019-12-09T15:29:45+0100">
#                 09-12-2019, 15:29
#               </time>
#               <span class="search-results__category">
#                                   in Binnenland                              </span>
#
#
#
#
#             </div>
#                           <div class="search-results__description">
#                 <p>Wetenschappelijk onderzoek heeft nu aangetoond dat een verantwoord plantaardig dieet resulteert in kwalitatief goede moedermelk.</p>
#               </div>
#                       </div>
#
#
#   <figure class="search-results__figure">
#
#
#
#
# 				<img alt="" class="search-results__image" src="https://cdn.nos.nl/image/2019/12/09/612898/320x180.jpg"/>
#
#   </figure>
#
#         </a>
#       </li>
#                 <li class="search-results__item">
#         <a class="search-results__link" href="/artikel/2382368-toch-geen-strengere-regels-voor-haver-en-sojadrink">
#           <div class="search-results__content">
#             <h3 class="search-results__title">Toch geen strengere regels voor haver- en sojadrink</h3>
#             <div class="search-results__meta">
#
#               <span class="icon-time icon-space-right"></span>
#
#               <time class="search-results__time" datetime="2021-05-26T11:35:07+0200">
#                 26-05-2021, 11:35
#               </time>
#               <span class="search-results__category">
#                                   in Economie                              </span>
#
#
#
#
#             </div>
#                           <div class="search-results__description">
#                 <p>Het Europarlement heeft een voorstel daarover ingetrokken.</p>
#               </div>
#                       </div>
#
#
#   <figure class="search-results__figure">
#
#
#
#
# 				<img alt="" class="search-results__image" src="https://cdn.nos.nl/image/2021/05/26/746370/320x180.jpg"/>
#
#   </figure>
#
#         </a>
#       </li>
#                 <li class="search-results__item">
#         <a class="search-results__link" href="/artikel/2404962-als-je-in-nederland-nog-elke-dag-vlees-eet-dan-ben-je-in-de-minderheid">
#           <div class="search-results__content">
#             <h3 class="search-results__title">'Als je in Nederland nog elke dag vlees eet, dan ben je in de minderheid'</h3>
#             <div class="search-results__meta">
#
#               <span class="icon-time icon-space-right"></span>
#
#               <time class="search-results__time" datetime="2021-11-09T14:25:39+0100">
#                 09-11-2021, 14:25
#               </time>
#               <span class="search-results__category">
#                                   in Economie                              </span>
#
#
#
#                               <span class="icon-camera icon-red icon-space-left"></span>
#
#             </div>
#                           <div class="search-results__description">
#                 <p>Veel mensen zeggen dat ze hun vleesconsumptie proberen te minderen en meer plantaardige alternatieven willen eten.</p>
#               </div>
#                       </div>
#
#
#   <figure class="search-results__figure">
#
#
#
#
# 				<img alt="" class="search-results__image" src="https://cdn.nos.nl/image/2021/11/09/801433/320x180.jpg"/>
#
#   </figure>
#
#         </a>
#       </li>
#                 <li class="search-results__item">
#         <a class="search-results__link" href="/artikel/2247497-veganisten-protesteren-in-amsterdam-tegen-hamburgers-en-bontjassen">
#           <div class="search-results__content">
#             <h3 class="search-results__title">Veganisten protesteren in Amsterdam tegen hamburgers en bontjassen</h3>
#             <div class="search-results__meta">
#
#               <span class="icon-time icon-space-right"></span>
#
#               <time class="search-results__time" datetime="2018-08-25T15:56:43+0200">
#                 25-08-2018, 15:56
#               </time>
#               <span class="search-results__category">
#                                   in Binnenland                              </span>
#
#
#
#                               <span class="icon-camera icon-red icon-space-left"></span>
#
#             </div>
#                           <div class="search-results__description">
#                 <p>Honderden mensen verzamelden zich om aandacht te vragen voor dierenwelzijn.</p>
#               </div>
#                       </div>
#
#
#   <figure class="search-results__figure">
#
#
#
#
# 				<img alt="" class="search-results__image" src="https://cdn.nos.nl/image/2018/08/25/495556/320x180.jpg"/>
#
#   </figure>
#
#         </a>
#       </li>
#                 <li class="search-results__item">
#         <a class="search-results__link" href="/nieuwsuur/artikel/2234918-is-rundvlees-eten-vervuilender-dan-autorijden">
#           <div class="search-results__content">
#             <h3 class="search-results__title">Is rundvlees eten vervuilender dan autorijden?</h3>
#             <div class="search-results__meta">
#
#               <span class="icon-time icon-space-right"></span>
#
#               <time class="search-results__time" datetime="2018-06-03T21:50:25+0200">
#                 03-06-2018, 21:50
#               </time>
#               <span class="search-results__category">
#                                   in Binnenland,                                   in Buitenland                              </span>
#
#                               <span class="icon-play icon-red icon-space-left"></span>
#
#
#
#             </div>
#                           <div class="search-results__description">
#                 <p>Nieuw onderzoek toont aan dat vooral je biefstukje relatief erg vervuilend is. De onderzoekers pleiten voor het veganisme: alle dierlijke producten van het menu geschrapt.</p>
#               </div>
#                       </div>
#
#
#   <figure class="search-results__figure">
#
#
#
#
# 				<img alt="" class="search-results__image" src="https://cdn.nos.nl/image/2017/04/13/369917/320x180.jpg"/>
#
#   </figure>
#
#         </a>
#       </li>
#                 <li class="search-results__item">
#         <a class="search-results__link" href="/artikel/2218583-nepleer-is-nu-ineens-veganistisch">
#           <div class="search-results__content">
#             <h3 class="search-results__title">'Nepleer is nu ineens veganistisch'</h3>
#             <div class="search-results__meta">
#
#               <span class="icon-time icon-space-right"></span>
#
#               <time class="search-results__time" datetime="2018-02-21T11:36:49+0100">
#                 21-02-2018, 11:36
#               </time>
#               <span class="search-results__category">
#                                   in Binnenland                              </span>
#
#
#
#
#             </div>
#                           <div class="search-results__description">
#                 <p>Meer schoenmerken willen zich een diervriendelijk imago aanmeten met schoenen van 'veganistisch leer'. Is dit echt een nieuw materiaal, of proberen winkels makkelijk te scoren?</p>
#               </div>
#                       </div>
#
#
#   <figure class="search-results__figure">
#
#
#
#
# 				<img alt="" class="search-results__image" src="https://cdn.nos.nl/image/2018/02/21/453663/320x180.jpg"/>
#
#   </figure>
#
#         </a>
#       </li>
#                 <li class="search-results__item">
#         <a class="search-results__link" href="/op3/artikel/2220527-waarom-wekt-de-week-zonder-vlees-zo-veel-irritatie-op">
#           <div class="search-results__content">
#             <h3 class="search-results__title">Waarom wekt de Week Zonder Vlees zo veel irritatie op?</h3>
#             <div class="search-results__meta">
#
#               <span class="icon-time icon-space-right"></span>
#
#               <time class="search-results__time" datetime="2018-03-04T08:25:49+0100">
#                 04-03-2018, 08:25
#               </time>
#               <span class="search-results__category">
#                                   in Binnenland                              </span>
#
#
#
#                               <span class="icon-camera icon-red icon-space-left"></span>
#
#             </div>
#                           <div class="search-results__description">
#                 <p>Sommigen laten komende week dat stukje vlees staan tijdens de Week Zonder Vlees. De een vindt het onzin, de ander vindt het noodzaak. Waarom ergeren vleeseters en vegetariërs zich soms aan elkaar?</p>
#               </div>
#                       </div>
#
#
#   <figure class="search-results__figure">
#
#
#
#
# 				<img alt="" class="search-results__image" src="https://cdn.nos.nl/image/2018/03/04/456605/320x180.jpg"/>
#
#   </figure>
#
#         </a>
#       </li>
#                 <li class="search-results__item">
#         <a class="search-results__link" href="/artikel/2208423-mcdonald-s-komt-met-mcvegan-over-15-jaar-zijn-alle-snacks-vega">
#           <div class="search-results__content">
# ...
#
#
#             </div>
#                           <div class="search-results__description">
#                 <p>Vanaf 28 december is de McVegan te koop in Zweden en Finland. Dat was te verwachten, zegt duurzame voedselexpert Marco Agema. </p>
#               </div>
#                       </div>
#
#
#   <figure class="search-results__figure">
#
#
#
#
# 				<img alt="" class="search-results__image" src="https://cdn.nos.nl/image/2017/12/19/438998/320x180.jpg"/>
#
#   </figure>
#
#         </a>
#       </li>
#                 <li class="search-results__item">
#         <a class="search-results__link" href="/nieuwsuur/video/2204560-veganisme-is-populair-maar-is-het-ook-gezond">
#           <div class="search-results__content">
#             <h3 class="search-results__title">Veganisme is populair, maar is het ook gezond?</h3>
#             <div class="search-results__meta">
#
#               <span class="icon-time icon-space-right"></span>
#
#               <time class="search-results__time" datetime="2017-11-25T19:06:49+0100">
#                 25-11-2017, 19:06
#               </time>
#               <span class="search-results__category">
#                                   in Binnenland                              </span>
#
#
#
#
#             </div>
#                           <div class="search-results__description">
#                 <p>Veganistische ijswinkels, veganistische producten in de supermarkt, veganistische restaurants. Veganisme is hip.</p>
#               </div>
#                       </div>
#
#
#   <figure class="search-results__figure">
#
#
#
#
# 				<img alt="" class="search-results__image" src="https://cdn.nos.nl/image/2017/11/25/433714/320x180.jpg"/>
#
#   </figure>
#
#         </a>
#       </li>
#                 <li class="search-results__item">
#         <a class="search-results__link" href="/nieuwsuur/artikel/2204524-veganisme-is-populair-maar-is-het-ook-gezond">
#           <div class="search-results__content">
#             <h3 class="search-results__title">Veganisme is populair, maar is het ook gezond?</h3>
#             <div class="search-results__meta">
#
#               <span class="icon-time icon-space-right"></span>
#
#               <time class="search-results__time" datetime="2017-11-25T15:50:09+0100">
#                 25-11-2017, 15:50
#               </time>
#               <span class="search-results__category">
#                                   in Binnenland                              </span>
#
#                               <span class="icon-play icon-red icon-space-left"></span>
#
#
#
#             </div>
#                           <div class="search-results__description">
#                 <p>Vooral in de Randstad eten mensen meer en meer plantaardige producten. Want veganisme is hip en lijkt een succes als nieuwe levensstijl. Maar doet een veganist zichzelf niet tekort?</p>
#               </div>
#                       </div>
#
#
#   <figure class="search-results__figure">
#
#
#
#
# 				<img alt="" class="search-results__image" src="https://cdn.nos.nl/image/2017/11/25/433641/320x180.jpg"/>
#
#   </figure>
#
#         </a>
#       </li>
#                 <li class="search-results__item">
#         <a class="search-results__link" href="/op3/artikel/2128277-veganisme-is-booming-business-in-israel">
#           <div class="search-results__content">
#             <h3 class="search-results__title">Veganisme is booming business  in Israël</h3>
#             <div class="search-results__meta">
#
#               <span class="icon-time icon-space-right"></span>
#
#               <time class="search-results__time" datetime="2016-08-26T14:04:59+0200">
#                 26-08-2016, 14:04
#               </time>
#               <span class="search-results__category">
#                                   in Buitenland                              </span>
#
#
#
#                               <span class="icon-camera icon-red icon-space-left"></span>
#
#             </div>
#                           <div class="search-results__description">
#                 <p>In Israël is de markt voor veganistische producten groot. Daardoor is er veel ruimte voor innovatie. Sinds kort kent het land bijvoorbeeld een veganistische chocoladefabriek.</p>
#               </div>
#                       </div>
#
#
#   <figure class="search-results__figure">
#
#
#
#
# 				<img alt="" class="search-results__image" src="https://cdn.nos.nl/image/2016/08/26/312204/320x180.jpg"/>
#
#   </figure>
#
#         </a>
#       </li>
#                 <li class="search-results__item">
#         <a class="search-results__link" href="/op3/artikel/2121930-veganburger-van-80-miljoen-smaakt-naar-vlees">
#           <div class="search-results__content">
#             <h3 class="search-results__title">Veganburger van 80 miljoen smaakt naar vlees</h3>
#             <div class="search-results__meta">
#
#               <span class="icon-time icon-space-right"></span>
#
#               <time class="search-results__time" datetime="2016-07-29T18:10:57+0200">
#                 29-07-2016, 18:10
#               </time>
#               <span class="search-results__category">
#                                   in Buitenland                              </span>
#
#
#
#
#             </div>
#                           <div class="search-results__description">
#                 <p>125 wetenschappers en 80 miljoen dollar hebben naar eigen zeggen de perfecte veganistische hamburger opgeleverd.</p>
#               </div>
#                       </div>
#
#
#   <figure class="search-results__figure">
#
#
#
#
# 				<img alt="" class="search-results__image" src="https://cdn.nos.nl/image/2016/07/29/303689/320x180.jpg"/>
#
#   </figure>
#
#         </a>
#       </li>
#                 <li class="search-results__item">
#         <a class="search-results__link" href="/artikel/2099574-discussierende-demonstranten-en-politie-botsen-in-parijs">
#           <div class="search-results__content">
#             <h3 class="search-results__title">Discussiërende demonstranten en politie botsen in Parijs</h3>
#             <div class="search-results__meta">
#
#               <span class="icon-time icon-space-right"></span>
#
#               <time class="search-results__time" datetime="2016-04-16T16:46:22+0200">
#                 16-04-2016, 16:46
#               </time>
#               <span class="search-results__category">
#                                   in Buitenland                              </span>
#
#                               <span class="icon-play icon-red icon-space-left"></span>
#
#
#
#             </div>
#                           <div class="search-results__description">
#                 <p>Al meer dan twee weken wordt in Parijs gediscussieerd en gedemonstreerd tegen sociale ongelijkheid. Vannacht liep het uit de hand.</p>
#               </div>
#                       </div>
#
#
#   <figure class="search-results__figure">
#
#
#
#
# 				<img alt="" class="search-results__image" src="https://cdn.nos.nl/image/2016/04/16/274396/320x180.jpg"/>
#
#   </figure>
#
#         </a>
#       </li>
#                 <li class="search-results__item">
#         <a class="search-results__link" href="/op3/artikel/2090859-gaat-het-nieuwe-vlees-het-oude-vlees-verslaan">
#           <div class="search-results__content">
#             <h3 class="search-results__title">Gaat het nieuwe vlees het oude vlees verslaan?</h3>
#             <div class="search-results__meta">
#
#               <span class="icon-time icon-space-right"></span>
#
#               <time class="search-results__time" datetime="2016-03-05T16:46:24+0100">
#                 05-03-2016, 16:46
#               </time>
#               <span class="search-results__category">
#                                   in Binnenland                              </span>
#
#
#
#                               <span class="icon-camera icon-red icon-space-left"></span>
#
#             </div>
#                           <div class="search-results__description">
#                 <p>Dit weekend staat de veganistenbeurs VeggieWorld voor het eerst in Nederland, in de Jaarbeurs in Utrecht. En daar is het druk.</p>
#               </div>
#                       </div>
#
#
#   <figure class="search-results__figure">
#
#
#
#
# 				<img alt="" class="search-results__image" src="https://cdn.nos.nl/image/2016/03/05/262111/320x180.jpg"/>
#
#   </figure>
#
#         </a>
#       </li>
#
#         </ul>
#     </div>
#
#   </div>
#
#   	</main>
#
# 	  	  	<footer id="footer">
#
#
#   <div class="row">
#     <div class="footer">
#       <div class="footer__container">
#         <div class="footer__column">
#           <h3 class="footer__logo">
#             <a href="/">
#               <span class="ir img-nos"> </span>
#               <span class="vh">NOS</span>
#             </a>
#           </h3>
#           <ul class="footer__list footer__list--visible-on-tablet">
#             <li class="footer__item">
#               <a class="footer__link" href="/nieuws">Nieuws</a>
#             </li>
#             <li class="footer__item">
#               <a class="footer__link" href="/sport">Sport</a>
#             </li>
#             <li class="footer__item">
#               <a class="footer__link" href="/uitzendingen">Uitzendingen</a>
#             </li>
#             <li class="footer__item">
#               <a class="footer__link" href="/teletekst">Teletekst</a>
#             </li>
#           </ul>
#         </div>
#
#         <div class="footer__column">
#           <h3 class="footer__title">Info</h3>
#           <ul class="footer__list footer__list--first">
#             <li class="footer__item">
#               <a class="footer__link" href="https://over.nos.nl/" rel="noreferrer noopener" target="_blank">Over de NOS</a>
#             </li>
#             <li class="footer__item">
#               <a class="footer__link" href="https://www.werkenbijdenos.nl/" rel="noreferrer noopener" target="_blank">Werken bij de NOS</a>
#             </li>
#             <li class="footer__item">
#               <a class="footer__link" href="https://over.nos.nl/adres-en-route/" rel="noreferrer noopener" target="_blank">Contact</a>
#             </li>
#             <li class="footer__item">
#               <a class="footer__link" href="https://over.nos.nl/journalistieke-verantwoording" rel="noreferrer noopener" target="_blank">Journalistieke verantwoording</a>
#             </li>
#             <li class="footer__item">
#               <a class="footer__link" href="/herstel">Herstelrubriek</a>
#             </li>
#           </ul>
#           <ul class="footer__list footer__list--sibling">
#             <li class="footer__item">
#               <a class="footer__link" href="https://ombudsman.npo.nl/" rel="noreferrer noopener" target="_blank">Ombudsman NPO</a>
#             </li>
#             <li class="footer__item">
#               <a class="footer__link" href="https://over.nos.nl/onze-programmas/53/nos-apps" rel="noreferrer noopener" target="_blank">NOS Apps</a>
#             </li>
#             <li class="footer__item">
#               <a class="footer__link" href="https://over.nos.nl/organisatie/regelgeving/" rel="noreferrer noopener" target="_blank">Voorwaarden</a>
#             </li>
#             <li class="footer__item">
#               <a class="footer__link" href="https://over.nos.nl/organisatie/privacy-reglement/" rel="noreferrer noopener" target="_blank">Privacy</a>
#             </li>
#           </ul>
#         </div>
#
#         <div class="footer__column footer__column--visible-on-tablet">
#           <h3 class="footer__title">Volg de NOS</h3>
#           <ul class="footer__list footer__list--first">
#             <li class="footer__item">
#               <a class="footer__link share__twitter" href="https://twitter.com/nos/" rel="noreferrer noopener" target="_blank">
#                 <span class="icons-wrap">
#                   <span class="icon-twitter share__icon"></span>
#                 </span>
#                 Twitter
#               </a>
#             </li>
#             <li class="footer__item">
#               <a class="footer__link share__facebook" href="https://www.facebook.com/nos" rel="noreferrer noopener" target="_blank">
#                 <span class="icons-wrap">
#                   <span class="icon-facebook share__icon"></span>
#                 </span>
#                 Facebook
#               </a>
#             </li>
#             <li class="footer__item">
#               <a class="footer__link share__instagram" href="https://instagram.com/nos/" rel="noreferrer noopener" target="_blank">
#                 <span class="icons-wrap">
#                   <span class="icon-instagram share__icon"></span>
#                 </span>
#                 Instagram
#               </a>
#             </li>
#           </ul>
#           <ul class="footer__list footer__list--sibling">
#             <li class="footer__item">
#               <a class="footer__link share__youtube" href="https://www.youtube.com/channel/UC5xziMuoFAOpX9mwUVhe2Jw/channels" rel="noreferrer noopener" target="_blank">
#                 <span class="icons-wrap">
#                   <span class="icon-youtube share__icon"></span>
#                 </span>
#                 YouTube
#               </a>
#             </li>
#             <li class="footer__item">
#               <a class="footer__link share__rss" href="/feeds" rel="noreferrer noopener" target="_blank">
#                 <span class="icons-wrap">
#                   <span class="icon-rss share__icon"></span>
#                 </span>
#                 RSS
#               </a>
#             </li>
#           </ul>
#
#           <div class="fb-button vh">
#             <div class="fb-like" data-action="like" data-href="https://facebook.com/nos" data-layout="button_count" data-share="false" data-show-faces="true">Like op Facebook</div>
#           </div>
#
#         </div>
#       </div>
#     </div>
#   </div>
#
#   <div class="row">
#     <div class="divide-top">
#       <ul class="list-disclaimer text-smaller">
#         <li class="list-disclaimer__item">
#                     <a class="npo_cc_settings_link link-hover" href="#">Cookie-instellingen</a>
#         </li>
#         <li class="list-disclaimer__item--right secret">
#           <span class=""><i class="secret__hover">©</i> NOS 2022</span>
#         </li>
#       </ul>
#     </div>
#   </div>
#
#   <a class="to-the-top js-scrollto" data-target="body" href="#nav" title="Terug naar boven">
#     <span class="vh">Naar boven</span>
#     <span class="icon-chevron-up icon-red"></span>
#   </a>
#
#   	</footer>
#
#           <script>var COMSCORE = null;</script>
#
#
# <script>
#   var ENV = 'prod';
#   var DOMAIN = 'preproduction';
#   var RECOMMENDATIONS = true;
#   var EVENTTRACKING = true;
#   var googletag = googletag || {};
# </script>
#
# <script src="https://component-renderer.api.nos.nl/components-with-bootloader.nos.client-only.297008b0c6b1beabd711.js"></script>
# <script src="https://cdn.nos.nl/assets/nos-symfony/be48190/build/js/runtime.js"></script>
# <script src="https://cdn.nos.nl/assets/nos-symfony/be48190/build/js/init.js"></script>
#
#   <script src="https://cdn.nos.nl/assets/nos-symfony/be48190/build/js/sites/nosnl.js"></script>
# <script class="js-site-page" src="https://cdn.nos.nl/assets/nos-symfony/be48190/build/js/pages/search.js"></script>
#   <script>
#     var DISABLE_SEARCH_NAV = true;
#   </script>
#
#
#       <script>
#       var TrackingEvent = window && window.NOS && window.NOS.TrackingEvent;
#       var tracker = window && window.NOS && window.NOS.tracker;
#
#       if (TrackingEvent && tracker) {
#         var pageViewEvent = new TrackingEvent({
#           type: 'pageview',
#           context: {
#             site: 'nos',
#             pageIdentifier: 'search',
#             searchTerm: 'veganisme',
#           },
#         });
#
#         tracker.track(pageViewEvent);
#       }
#     </script>
#
#
#
#
# </body></html>

# %% [markdown]
# ## 2. Collecting results

# %% [markdown]
# If you inspect the search results, you can see that they have different properties such as *title*, *time*, and *category*. It would be possible, to filter our results based on these categories. For the moment, we only want to collect the links to the articles in a list.
#
# We iterate through all links, send a request and extract the text. Then we store the text in a file.

# %%
# Extract only the class a.search-results__link
links = parser_content.select("a.search-results__link")

domain = "https://nos.nl"

for i, link in enumerate(links):    
    found_url = domain + link["href"]
    print(found_url)
    
    # Extract text and add the url as first line
    text = found_url + '\n'+ url_to_string(found_url) 
    
    # Save in file
    dir = "../results/nos_search_results/"
    filename = keyword + "_" + str(i) + ".txt"
    with open(dir + filename, "w", encoding = "utf-8") as f:
        f.write(text)
# Out:
# https://nos.nl/artikel/2309909-ellen-degeneres-krijgt-golden-globe-oeuvreprijs
# https://nos.nl/artikel/2314011-veganistische-moeder-niet-langer-geweerd-van-moedermelkbank
# https://nos.nl/artikel/2382368-toch-geen-strengere-regels-voor-haver-en-sojadrink
# https://nos.nl/artikel/2404962-als-je-in-nederland-nog-elke-dag-vlees-eet-dan-ben-je-in-de-minderheid
# https://nos.nl/artikel/2247497-veganisten-protesteren-in-amsterdam-tegen-hamburgers-en-bontjassen
# https://nos.nl/nieuwsuur/artikel/2234918-is-rundvlees-eten-vervuilender-dan-autorijden
# https://nos.nl/artikel/2218583-nepleer-is-nu-ineens-veganistisch
# https://nos.nl/op3/artikel/2220527-waarom-wekt-de-week-zonder-vlees-zo-veel-irritatie-op
# https://nos.nl/artikel/2208423-mcdonald-s-komt-met-mcvegan-over-15-jaar-zijn-alle-snacks-vega
# https://nos.nl/nieuwsuur/video/2204560-veganisme-is-populair-maar-is-het-ook-gezond
# https://nos.nl/nieuwsuur/artikel/2204524-veganisme-is-populair-maar-is-het-ook-gezond
# https://nos.nl/op3/artikel/2128277-veganisme-is-booming-business-in-israel
# https://nos.nl/op3/artikel/2121930-veganburger-van-80-miljoen-smaakt-naar-vlees
# https://nos.nl/artikel/2099574-discussierende-demonstranten-en-politie-botsen-in-parijs
# https://nos.nl/op3/artikel/2090859-gaat-het-nieuwe-vlees-het-oude-vlees-verslaan

# %% [markdown]
# ## 3. Inspecting data

# %% [markdown]
# Once you collected your preliminary data, the most important pre-processing phase begins: **Data Analyis**.
#
# Inspect the collected files and examine the following aspects:
# - Are the articles related to the topic that you had in mind when choosing the keyword? Or do you need to re-adjust the query? Many search engines allow you to use combinations of keywords using regular expressions in your queries.
# - Is the data structure of the results homogeneous?
# - How useful is the extracted text? What kind of additional data pre-processing would be helpful? How could you do that?
# - Can you identify different thematic groups or perspectives in the results? Are the differences reflected in the language?

# %% [markdown]
# **Try out other public APIs to collect texts from interesting sources. You can find some examples here: https://github.com/public-apis/public-apis. Experiment with data from different languages.**
#
# How do you need to adjust the code?
#
# Note: Many APIs require that you register and obtain an API Key. This key is an identifier that you add to the query. It controls the number of queries that you send to avoid abuse.
