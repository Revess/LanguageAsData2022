# %% [markdown]
# Copyright: Vrije Universiteit Amsterdam, Faculty of Humanities, CLTL

# %% [markdown]
# # Lab 1.3: Querying tweets

# %% [markdown]
# In this notebook, we are going to query Twitter streams using the library *tweepy*. Take a look at its [documentation](https://github.com/tweepy/tweepy/tree/master/docs)
#
# Tweepy allows you to access Twitter using credentials and returns a so-called Cursor object. From the Cursor object, you can access the twitter data in e.g. JSON format. Documentation on the Twitter data objects can be found [here](https://developer.twitter.com/en/docs)
#
#
# Make sure you installed the package and obtained the Twitter credentials before your start using the API.
#
# https://www.earthdatascience.org/courses/use-data-open-source-python/intro-to-apis/twitter-data-in-python/

# %% [markdown]
# ## 1. Setting up your twitter credentials to use the API

# %% [markdown]
# First of all you need to have a standard Twitter account. It is easy to create a dummy account and you do not have to use your own name. It is okay, if you do not want to register for a Twitter account. In this case, you cannot test or modify the code. You need to make sure that you still understand how this works.
#
# 1. Log in to your twitter account and go to developer.twitter.com
# 2. Click on “Apply” in the top right and then on “Apply for a developer account”
# 3. Choose “Academic”, then “Student” and “Get started” and fill in the required fields.
# 4. Use the following text block for all text fields and mark questions 1 and 3 “yes“ and 2 and 4 "no":
# `Text Mining course at the VU university master program of the faculty of humanities. We analyse tweets for extracting data and information and obtaining statistics on language use. Analyses will be described in a password-protected blog. I am a student in this course"`
# 5. Read the Developer agreement and policy and agree (if you agree). Confirm the email and obtain the credentials.
#
# Set the constants API_KEY and API_Secret to your values:

# %%
import tweepy
# The API-Key and the API-secret were displayed to you after you registered
API_KEY = 'dRmenPFIsVZKJf5CmIQNU7llD'
API_SECRET = 'zjQGivfPknrs1lmGAD8ksAiXgKvzTt8ZVip2dTEJZQOYg29iRg'

# %% [markdown]
# 6. Go to the developer portal, then Project and Apps, and create a Standalone App. Fill in a name for your app, it can be anything, e.g. ‘YOURNAME_Lab1”. Copy the access token and secret and store it in a file.

# %%
# The Access token and the Access secret were displayed when you clicked on "generate"
ACCESS_TOKEN = '1413630811656622088-JzdmaxIrXXCnXuUpxdjWOs51L4YFxr'
ACCESS_SECRET = '2YQs4uuYag6hQ1DTaBZyggq2HOC5dx9WYyGmZQR979EfC'

# %% [markdown]
# # 2. Querying the Twitter API

# %% [markdown]
# We are using Tweepy to crawl tweets, but it is important to know that it has some limitations that affect reproducibility. The Twitter API is not exhaustive, it simply provides a sample and the documentation does not provide much detail on how this sample is determined. https://stackoverflow.com/questions/32445553/tweepy-not-finding-results-that-should-be-there

# %% [markdown]
# The Twitter API returns the results as a JSON object. You learned how to use JSON objects in [Chapter 17](https://github.com/cltl/python-for-text-analysis/blob/master/Chapters/Chapter%2017%20-%20%20Data%20formats%20II%20(JSON).ipynb) of the Python course. The tweepy library makes it easier to access these JSON objects.
#
# The code below is used to set up the connection:

# %%
import tweepy

# Setup the authentication with your Twitter credentials:
auth = tweepy.OAuthHandler(API_KEY, API_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

# Create the api to connect to Twitter using your authentication 
api = tweepy.API(auth, wait_on_rate_limit=True)

# %% [markdown]
# We set a few variables to limit our search. Note that we can include hashtags and words in our keywords and combine them using Boolean operators such as OR and AND. Check the [Twitter API documentation](https://developer.twitter.com/en/docs/twitter-api/v1/rules-and-filtering/overview/standard-operators) for more details on how to customize queries.
#
# **Play around with the parameters and understand how the queries are composed.**

# %%
#We define the keywords in our target language
language = "pt"
keywords = "(#trump)"

# Optional: we can define a filter, for example, to ignore retweets
filter = "-filter:retweets"

query = keywords + filter

# # Optional: Limit the number of tweets  
count = 500

# Request the tweets
tweet_iterator = api.search_tweets(q=query,lang=language,count=count)

# We save the tweets as a list, so that we can access them later. 
tweets = list(tweet_iterator)   

for i, tweet in enumerate(tweets): 
    print(i)
    print("User:" + tweet.user.screen_name)
    print("Tweet:" + tweet.text)
    print()
# Out:
# 0
# User:AlexandreCmps70
# Tweet:Marcha das mulheres que não aceitam o resultado das eleições 2022.#bbc #londres #EUA #Putim #Trump #TheTimes… https://t.co/sPef5rcnl5
#
# 1
# User:AlexandreCmps70
# Tweet:Brasileiros nas ruas contra resultado das eleições presidenciais 2022.#bbc #londres #EUA #Putim
# #Trump… https://t.co/rn9TdMkMAT
#
# 2
# User:AlexandreCmps70
# Tweet:Criancas nas ruas contra resultado das eleições presidenciais 2022.#bbc #londres #EUA #Putim
# #Trump… https://t.co/MlTCDv6yvK
#
# 3
# User:AlexandreCmps70
# Tweet:Brasileiros nas ruas contra resultado das eleições presidenciais 2022.#bbc #londres #EUA #Putim
# #Trump… https://t.co/a938y5302o
#
# 4
# User:AlexandreCmps70
# Tweet:Brasileiros nas ruas contra resultado das eleições presidenciais 2022.#bbc #londres #EUA #Putim
# #Trump… https://t.co/vpuFRrAYZi
#
# 5
# User:AlexandreCmps70
# Tweet:Brasileiros clamam pelas forças armadas e pedem SOS Forças.#bbc #londres #EUA #Putim
# #Trump #TheGlobeandMail… https://t.co/w2JWb6bXUI
#
# 6
# User:AlexandreCmps70
# Tweet:Brasileiros nas ruas contra resultado das eleições presidenciais 2022.#bbc #londres #EUA #Putim
# #Trump… https://t.co/WPQ7IcdIVa
#
# 7
# User:AlexandreCmps70
# Tweet:Os brasileiros não aceitam o resultado das eleições presidenciais 2022.#bbc #londres #EUA #Putim
# #Trump… https://t.co/jTwJtUMA9O
#
# 8
# User:marinhos
# Tweet:Troquem Republicanos por bolsonaristas.
# Troquem Trump por Bozo.
# A desonra fica, como de todos os golpistas, com mu… https://t.co/2ns9nrw26H
#
# 9
# User:realrosi5
# Tweet:Ditador brasileiro em Nova Iork #Brasilia #BrazilianSpring #Bolsonaro #Trump #SaveBrazil #help https://t.co/gaHGsJgrJ8
#
# 10
# User:vascogargalo
# Tweet:He is back | cartoon editorial da revista de Domingo do @correiodamanhaoficial
#
# #usa #midterms2022 #biden #trump… https://t.co/CYl3a4e3CC
#
# 11
# User:esmaelmorais
# Tweet:Deu ruim para o Trump: democratas mantiveram o controle do Senado https://t.co/rhJAreNyM0 #Trump #Senado https://t.co/stZoPEAwcL
#
# 12
# User:MoreiraMenesesD
# Tweet:As #eleições de meio de mandato nos #EUA frustram os planos de #Trump e dão novo fôlego a #JoeBiden.
#
# 13
# User:catarinalmoc
# Tweet:Como disse o grande filósofo Tchakabum: Onda onda, olha a onda
# Onda onda, olha a onda
# Vai te molhar, vai te banhar,… https://t.co/VV4DgiKbPw
#
# 14
# User:KyTransgender
# Tweet:Senate    #Trump https://t.co/aFEWwuXQxq
#
# 15
# User:parego
# Tweet:Grande mídia americana vai tentar se livrar de #Trump 🤢🤮tentando promover #DeSantis 🤢🤮 como um político "normal" e… https://t.co/6kCVadWgwT
#
# 16
# User:Jimbokli1
# Tweet:1776 Ultra MAGA T-shirt FJB Logo https://t.co/0iHhdTetAj #Ultramaga #1776ULTRAMAGA #Fjb #Trump2024 #Trump… https://t.co/wQoGndMPRl
#
# 17
# User:EliadePalma
# Tweet:URGENTE!!! COMPARTILHEM.
#
# #eleicoes2022 #eleicões22 #bolsonaro #brasil #brazil #brazilnews #tse #noticias #noticia… https://t.co/wMrfltDjxH
#
# 18
# User:and_lnl
# Tweet:@joicehasselmann O #Trump vai esperar um pouco pra tentar fechar contigo, @joicehasselmann.
#
# Seus votos são muito importantes pra ele 😅😂🤣
#
# 19
# User:herculesmarque1
# Tweet:@roxmo Hashtag para colocarem nas publicações
#
# #nytimes #nyc #cnn #washingtonpost #newyorktimes #ny #newyork… https://t.co/aTfXE1KO31
#
# 20
# User:PlenoNews
# Tweet:EUA: Apoiador de Trump, filho de brasileiros é eleito deputado #Trump #brasileiros #GeorgeSantos #PlenoNews
#
# https://t.co/K8ev7sBEUM
#
# 21
# User:ApocalipseUrg
# Tweet:Trump é mais popular que Jesus no Twitter https://t.co/ESNpF4Fvsc
#
# No Twitter, usuários americanos deixaram de usar… https://t.co/AD1dmDf4g9
#
# 22
# User:parego
# Tweet:Otima coluna @FareedZakaria no @Estadao
# Batalha dentro do partido Republicano para 2024 vai ser entre #Trump Vs… https://t.co/hujxMfqm4G
#
# 23
# User:julianaayres
# Tweet:Conselho do Trump para os jovens;
#
# #video #trump #reflexao https://t.co/jBJXPn2gcT
#
# 24
# User:Jornal_Canyons
# Tweet:🇺🇸 #Trump publica diversas alegações falsas sobre as eleições de meio de mandato.
#
# 25
# User:radiopampapoa
# Tweet:COP 27: Biden se desculpa por Trump tirar os Estados Unidos do Acordo de Paris:
#
# Leia em https://t.co/OrRcY1c4cn (l… https://t.co/zrxwjRdcrn
#
# 26
# User:TioMksbrasil
# Tweet:@PedroRonchi2 Será que não tem nada pra esconder,ou aluno assíduo de #Trump
#
# 27
# User:ConservNewsDly
# Tweet:Florida Republican Sen.... #BreakingNews #conservative #ConservativeNews #trump #republican
#
# https://t.co/8y2QlLjMI5
#
# 28
# User:brasil_felix
# Tweet:Será que vamos precisar defender nosso país de uma intervenção internacional?? Tempos sombrios 🥺
# #FFAAsalvemOBrasil… https://t.co/p48o1ewOhs
#
# 29
# User:TiagoDinizPorto
# Tweet:Sem dúvida (embora, como nas lagartixas, durante algum tempo o rabo ainda se consegue mexer, depois de separado do… https://t.co/2hcCOwiBPK
#
# 30
# User:TiagoDinizPorto
# Tweet:@DiogoRo76871614 Sem dúvida (embora, como nas lagartixas, durante algum tempo o rabo ainda se consegue mexer, depoi… https://t.co/Rkq74i76MS
#
# 31
# User:realalexvieira
# Tweet:Vamos La Embora Caralho. Americanos Levam Porrada Pela Esquerda e Direita. Nem Sabem Donde Elas Veem 🥳 🇺🇦  $TSLA… https://t.co/YRHuOFGGFo
#
# 32
# User:TioMksbrasil
# Tweet:@lelispatricia Mas deve ter ☁️☁️☁️ por aí...
# Copiando #Trump?
#
# 33
# User:obnoxiousdad_4
# Tweet:MAGA: "DeSAntis Is A Rino
#
# Meanwhile RINOS attack DeSantis.
#
# #MAGA #TRUMP #GOP #Midterms2022 https://t.co/YbKavmESdH
#
# 34
# User:Margare90939617
# Tweet:@ThiagoResiste Só pode ser coisa do #Trump com  o #Bozo
#
# 35
# User:tvcultura
# Tweet:Após amargarem decepção nas eleições de meio de mandato, conservadores intensificam críticas ao ex-presidente.… https://t.co/6H8Ol5JxsK
#
# 36
# User:jornal_cultura
# Tweet:Após amargarem decepção nas eleições de meio de mandato, conservadores intensificam críticas ao ex-presidente.… https://t.co/mmlgq8fQgE
#
# 37
# User:FilipeGarcia
# Tweet:Com a  introdução do termo #invotável na imprensa nacional ;)
# As ‘midterm’ podem ter sido ao mesmo tempo más para T… https://t.co/7pZdNNhDR7
#
# 38
# User:MoreiraMenesesD
# Tweet:#Trump perde força após #eleições de meio de mandato nos #EUA.
#
# 39
# User:GhirottiPaola
# Tweet:Interessante #putin #trump #biden #russia #usa #MidtermElections2022 #midterm #hunterbiden #donbass #ue… https://t.co/2odoa82iJ7
#
# 40
# User:cincyredbengal
# Tweet:@ajzeigler CUCKSANTIS IS A RINO🐸🐸🐸🐸 #Trump2024 #Trump #Trump2024 #TRUMP2024ToSaveAmerica
#
# 41
# User:Jornal_Canyons
# Tweet:🇺🇸 #Trump não reage bem e "grita com todos" após desempenho de partido nas eleições.
#
# 👉 #JornaldosCanyons • #JdC
#
# 42
# User:jornalodia
# Tweet:Aliados do ex-presidente dizem que agora o foco total do partido precisa estar na Geórgia.
#
# #Trump #Eleição #ODia
#
# https://t.co/nNLu9YSKqO
#
# 43
# User:RMills08
# Tweet:@samanthamarika1 #Trump/Paul2024
#
# 44
# User:AlexandreGossn
# Tweet:O que as eleições do meio nos EUA podem representar ao futuro de Bolsonaro como eventual líder da oposição no Brasi… https://t.co/njIfjDQUvr
#
# 45
# User:portalR7
# Tweet:#Republicanos  se aproximam da maioria na Câmara dos Deputados dos EUA; Senado segue incerto
#
# O partido de #Trump… https://t.co/WUXnSHzQUF
#
# 46
# User:FabioViana53
# Tweet:Não queremos copa do mundo, queremos Lula e o cabeça de ovo na cadeia. #ministeriodadefesa #Trump #BrazilSpring
#
# 47
# User:dialogosdosul
# Tweet:No Rodamundo desta segunda (7), a cientista política explica que as midterms, as eleições de meio de mandato nos EU… https://t.co/prusDf86hV
#
# 48
# User:Marmottist
# Tweet:Curpa de Melania #Midterms2022 #Trump https://t.co/SnoSes4dQp
#
# 49
# User:erregege1
# Tweet:#Trump não reage bem e "grita com todos" após desempenho de partido nas eleições. #Election2022
# https://t.co/Z62Hm0nATd
#
# via @GoogleNews
#
# 50
# User:erregege1
# Tweet:#Trump ameaça revelar informações pouco lisonjeiras sobre DeSantis se este entrar na corrida presidencial em 2024.… https://t.co/eLOoNp6Pax
#
# 51
# User:dialogosdosul
# Tweet:O total de fundos privados gastos nestas eleições já chega a US$ 7,5 bilhões, o que supera o recorde das midterms d… https://t.co/B8481yT35F
#
# 52
# User:FabioViana53
# Tweet:Ptistas indo comer a "PICANHA"
# #ministeriodadefesa #LulaLadrao #Trump #ElonMusk #BrasilianSprings #ForaLula… https://t.co/xhWHjvSLwp
#
# 53
# User:FabioViana53
# Tweet:Serão 4 anos de comunismo para que aprendam a valorizar a bênção que é o governo de DIREITA. #ministeriodadefesa… https://t.co/rLTFyAsCTl
#
# 54
# User:Anny10193187
# Tweet:Veja o vídeo até o fim e entenda o poder que o povo tem e não sabe ! #Resistenciacivil #ResistenciaCivilBrasil… https://t.co/9bhuLE8Odb
#
# 55
# User:Cleber_Sans
# Tweet:Aquela foto que lhe conta tudo…
#
# #braziliansprings
# #Trump https://t.co/nF0er9Va6x
#
# 56
# User:FabioViana53
# Tweet:Ex delegado Protógenes Queiroz que comandou a operação Satiagraha fez denúncia gravíssima sobre a fraude nas urnas,… https://t.co/yxM16YPOiw
#
# 57
# User:renanlubawski
# Tweet:FORÇA BRASIL! A LUTA AINDA NAO ACABOU!
#
# #BrazilianSpring #BRAZILNEEDHELP #Trump #FRAUDE #SOSFFAA #TaNaRede… https://t.co/MxxVWweDX2
#
# 58
# User:realalexvieira
# Tweet:Passei o Dia a Espancar Americanos e a Beber Shots em Frente ao Mar com Musica da Ucrania 🥳 🇺🇦  $TSLA $QQQ $SPY… https://t.co/eaWQ3s6R1j
#
# 59
# User:seu_dinheiro_br
# Tweet:A onda conservadora flopou? Republicanos devem ganhar a Câmara nos EUA, mas democratas obtêm vitórias surpreendente… https://t.co/vOErmuLeN6
#
# 60
# User:ninacolares22
# Tweet:#Repost @eduarda_campopiano
# ——
# Brazil's in great danger! Compartilhe o máximo!
#
# @jasonmillerindc
# @donaldjtrumpjr… https://t.co/v84exQqNos
#
# 61
# User:realalexvieira
# Tweet:Um Americano e Um Macaco Com 2 Olhos e Um Grande Rabo Para Apanhar Porrada. Da-lhe Com Forca Todos os Dias 🥳 🤣… https://t.co/owuX5xk7A1
#
# 62
# User:revamaral
# Tweet:O tal tsunami vermelho de #Trump parece ter morrido na praia.
# Conversei hoje pela manhã sobre as eleições de meio d… https://t.co/gBbfgHD4XL
#
# 63
# User:Soulzian11
# Tweet:The Orange man is back ! MAGA🇺🇸
#
# Trump foi o maior aliado internacional de Bolsonaro e igualmente teve sua vitória… https://t.co/FT2NqGUk0T
#
# 64
# User:realalexvieira
# Tweet:Vamos La Caralho! A Ordem e para Estripar. Tira-lhe os Olhos. Fura o Craneo 🥳 🤣 $TSLA $QQQ $SPY #crypto $AAPL #news… https://t.co/q6Av1teHXi
#
# 65
# User:realalexvieira
# Tweet:Vamos La Caralho! Rebenta Com os Americanos! Democratas e Republicanos. Puta Que os Pariu 🥳 🤣 $TSLA $QQQ $SPY… https://t.co/2RWh1tDFwM
#
# 66
# User:Grandes_atos
# Tweet:Vem muito trabalho pela frente 😃😃
#
# #eleicoesEUA #Trump https://t.co/wv2kWBuInv
#
# 67
# User:thecrownsirius
# Tweet:#Trump está de volta Loading.....82% https://t.co/Tc0hISI3GF
#
# 68
# User:texdelio
# Tweet:#Trump deve começar a ficar preocupado com o Republicano moderado #DeSantis ?
#
# 69
# User:realalexvieira
# Tweet:Foda-se Vamos La Embora Rebentar com os Americanos. Junta-te ao #cryptocrash  🥳 🇺🇦 $TSLA $QQQ $SPY #crypto $AAPL… https://t.co/IP0N05IYFM
#
# 70
# User:JornalSomos
# Tweet:Projeções para Câmara apontam vitória Republicana nas eleições de meio mandato
#
# https://t.co/5Qm0oGJAC6
#
# #Biden… https://t.co/kcDDMxv0uj
#
# 71
# User:realalexvieira
# Tweet:Foda-se Vamos La Embora Rebentar com os Americanos. ESMAGA! O Ultimo e Gay 🥳 🤣 $TSLA $QQQ $SPY #crypto $AAPL #news… https://t.co/qVOY2TdExz
#
# 72
# User:froes_renatinha
# Tweet:PRA BOM ENTENDEDOR... 👏🏽👏🏽👏🏽🤣🇺🇸🇧🇷🏆
# #Trump https://t.co/pyZTHEGOxB
#
# 73
# User:realalexvieira
# Tweet:Foda-se Vamos La Embora Rebentar com os Americanos. O Ultimo e Gay 🥳 🤣 $TSLA $QQQ $SPY #crypto $AAPL #news #bitcoin… https://t.co/gEmBTWVVKu
#
# 74
# User:cabral_jhonmet
# Tweet:#Trump voltando para sua timeline 😎 a esquerda chega fica arrupiada kkkkkkkk @DanielSiade @Jefersonn__1… https://t.co/FBgAp6eCHz
#
# 75
# User:Henriops
# Tweet:Suposto encontro de lula hj com autoridades políticas . Reparem onde o dedo está apontando. Kkkk montagem das braba… https://t.co/KIYDxJ6mY5
#
# 76
# User:fernandakmella
# Tweet:#Trump é um homem forte 💪! E cheio de princípios e valores conservadores! Só isso faz dele diferenciado e sair da m… https://t.co/kpT77C0TER
#
# 77
# User:drochaa8
# Tweet:Além das expectativas que os brasileiros estão com o desfecho das #Eleicoes2022  no Brasil, observam em paralelo, o… https://t.co/hmN92llaRk
#
# 78
# User:NandaahFagundes
# Tweet:Tentando subir a vaquinha aq novamente 🙏🥺 Ajudem por favor 🙏🙏
# Link da vaquinha: https://t.co/f0GRtUQajz… https://t.co/P8Y6wluMUg
#
# 79
# User:eagorameu
# Tweet:@TSEjusbr @ufpeoficial @unicampoficial @usponline um pouco arrogância de quem acha que está acima de tudo e todos,… https://t.co/tpXkbIDylo
#
# 80
# User:PauloCezarOPc1
# Tweet:Cara é triste vc ver um “pastor” incitando o povo contra poderes constituídos. #Trump https://t.co/yCmV3bMbrg
#
# 81
# User:_Erika_Dias
# Tweet:Cansativo isso … desde as eleições de ‘18 a mesma estória ! Não deu certo com #trump e não dará aqui !… https://t.co/Waen1NU99k
#
# 82
# User:itaboraisantos
# Tweet:Eleições Americanas #democratas #republicanos #trump #biden https://t.co/qVzsdWc2tJ
#
# 83
# User:MikhaelTeixeira
# Tweet:Lula disse que está em Brasília. Alguém viu ele? Nao Vale foto antiga.  Cade o lula?
#
# #Trump #Censura
#
# 84
# User:EpochTimesPT
# Tweet:O ex-presidente Donald Trump falou em dois eventos nos EUA. Trouxemos hoje trechos dublados de seu discurso.
# #Trump https://t.co/Bjt2DTYM0u
#
# 85
# User:thedim_thainan
# Tweet:Faz o L
#
# #Politica
# #eleiçoes2022
# #LulaLadrao
# #PTNuncaMais
# #lulateenganou
# #Bolsonaro22
# #BolsonaroReeleito… https://t.co/Hnpw1N4geA
#
# 86
# User:TPredicator2
# Tweet:@TalCualOficial @carlossaldar44 @SenadoGovCo @CamaraColombia @RoyBarreras @DavidRacero @JuanDiegoEcha14 @ahmonedero… https://t.co/obThI15TIQ
#
# 87
# User:RubenBeltranG
# Tweet:Ídem: #Trump https://t.co/TaFUq84Z5r
#
# 88
# User:BrenoGomes30
# Tweet:A direita segue crescendo mais forte do que nunca nos Estados Unidos ❤️🇺🇸
#
# #Trump #Trump2024
#
# 89
# User:luapfsouza
# Tweet:OLHA O LOIRÃO #Trump  CHEGANDO PARA A NOSSA  FELICIDADE !
#
# ESTA É A ÚNICA ONDA VERMELHA QUE A GENTE QUER SURFAR!!… https://t.co/b51kjkiiw2
#
# 90
# User:pvbraguinha
# Tweet:Pra entender essa cena eu recomendo a leitura do livro - A revolução dos bichos. #Election2022 #biden #maduro #Trump https://t.co/ljWlCR6nwh
#
# 91
# User:TioMksbrasil
# Tweet:@Brasil08704642 4/
# De um lado o #OtavioCarvalho
# #SteveBannon
# #Trump
# #Putin e a máquina de Bots dele, que aliás mex… https://t.co/9ccibJPaTE
#
# 92
# User:afonsomopra
# Tweet:Até eu que sou um afegão médio #brazuela Brazil Was Stolen #BrazilianSpring #CensuraNao Monark #Trump… https://t.co/VxHsXbiIBt
#
# 93
# User:Brunogrunge6
# Tweet:O ano é 2022, Bolsonaro ganha a eleição por uma diferença de 2 milhões de votos e os Petistas vão pra rua questiona… https://t.co/nnAzEFQQNO
#
# 94
# User:wilkerDias13
# Tweet:As coisas nos EUA não estão boas para Biden. O partido RP está a levar vantagem na Câmara dos Representantes e os D… https://t.co/sUWrjiXgsk
#
# 95
# User:zidanenhume
# Tweet:#Trump ganhou as eleições de novo. Aquele é o cara.
#
# 96
# User:supra_blog
# Tweet:O desespero de terraplanistas e negacionistas ao descobrirem que o Brasil segue em frente
#
# Leia… https://t.co/0BlK4VTICo
#
# 97
# User:fyde456
# Tweet:#Republicanos eu jamais quero está do lado de #trump
#
# 98
# User:Flaviosr_1
# Tweet:Volta logo #Trump
#
# 99
# User:aeduardooficial
# Tweet:Boa Noite 🇧🇷🇺🇲 #Trump #GoTRUMP https://t.co/GQYyAQX2Jj

# %% [markdown]
# # 3. Examining the attributes
#
# In the above code, we only check the username and the text of the tweet. The result that the API returns contains much more information that might be interesting for your analyses. Let's take a look at the attributes of the first tweet in our result list.
#
# **Discuss which of these properties would be interesting for your analysis.**

# %%
# Show all attributes of a tweet that you can access
tweets[0].__dict__
# Out:
# {'_api': <tweepy.api.API at 0x7f13505976a0>,
#  '_json': {'created_at': 'Mon Nov 14 08:40:56 +0000 2022',
#   'id': 1592075096130199553,
#   'id_str': '1592075096130199553',
#   'text': 'Marcha das mulheres que não aceitam o resultado das eleições 2022.#bbc #londres #EUA #Putim #Trump #TheTimes… https://t.co/sPef5rcnl5',
#   'truncated': True,
#   'entities': {'hashtags': [{'text': 'bbc', 'indices': [66, 70]},
#     {'text': 'londres', 'indices': [71, 79]},
#     {'text': 'EUA', 'indices': [80, 84]},
#     {'text': 'Putim', 'indices': [85, 91]},
#     {'text': 'Trump', 'indices': [92, 98]},
#     {'text': 'TheTimes', 'indices': [99, 108]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/sPef5rcnl5',
#      'expanded_url': 'https://twitter.com/i/web/status/1592075096130199553',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [110, 133]}]},
#   'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1397939023545503744,
#    'id_str': '1397939023545503744',
#    'name': 'Alexandre Campos',
#    'screen_name': 'AlexandreCmps70',
#    'location': 'Duas Barras, Brasil',
#    'description': 'O desejo cria, o pensamento atraí, a fé realiza!',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 13,
#    'friends_count': 128,
#    'listed_count': 0,
#    'created_at': 'Thu May 27 15:33:44 +0000 2021',
#    'favourites_count': 853,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 753,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1408010937324482563/6Ez-JJ-k_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1408010937324482563/6Ez-JJ-k_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'pt'},
#  'created_at': datetime.datetime(2022, 11, 14, 8, 40, 56, tzinfo=datetime.timezone.utc),
#  'id': 1592075096130199553,
#  'id_str': '1592075096130199553',
#  'text': 'Marcha das mulheres que não aceitam o resultado das eleições 2022.#bbc #londres #EUA #Putim #Trump #TheTimes… https://t.co/sPef5rcnl5',
#  'truncated': True,
#  'entities': {'hashtags': [{'text': 'bbc', 'indices': [66, 70]},
#    {'text': 'londres', 'indices': [71, 79]},
#    {'text': 'EUA', 'indices': [80, 84]},
#    {'text': 'Putim', 'indices': [85, 91]},
#    {'text': 'Trump', 'indices': [92, 98]},
#    {'text': 'TheTimes', 'indices': [99, 108]}],
#   'symbols': [],
#   'user_mentions': [],
#   'urls': [{'url': 'https://t.co/sPef5rcnl5',
#     'expanded_url': 'https://twitter.com/i/web/status/1592075096130199553',
#     'display_url': 'twitter.com/i/web/status/1…',
#     'indices': [110, 133]}]},
#  'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#  'source': 'Twitter for Android',
#  'source_url': 'http://twitter.com/download/android',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'author': User(_api=<tweepy.api.API object at 0x7f13505976a0>, _json={'id': 1397939023545503744, 'id_str': '1397939023545503744', 'name': 'Alexandre Campos', 'screen_name': 'AlexandreCmps70', 'location': 'Duas Barras, Brasil', 'description': 'O desejo cria, o pensamento atraí, a fé realiza!', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 13, 'friends_count': 128, 'listed_count': 0, 'created_at': 'Thu May 27 15:33:44 +0000 2021', 'favourites_count': 853, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 753, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1408010937324482563/6Ez-JJ-k_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1408010937324482563/6Ez-JJ-k_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, id=1397939023545503744, id_str='1397939023545503744', name='Alexandre Campos', screen_name='AlexandreCmps70', location='Duas Barras, Brasil', description='O desejo cria, o pensamento atraí, a fé realiza!', url=None, entities={'description': {'urls': []}}, protected=False, followers_count=13, friends_count=128, listed_count=0, created_at=datetime.datetime(2021, 5, 27, 15, 33, 44, tzinfo=datetime.timezone.utc), favourites_count=853, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=753, lang=None, contributors_enabled=False, is_translator=False, is_translation_enabled=False, profile_background_color='F5F8FA', profile_background_image_url=None, profile_background_image_url_https=None, profile_background_tile=False, profile_image_url='http://pbs.twimg.com/profile_images/1408010937324482563/6Ez-JJ-k_normal.jpg', profile_image_url_https='https://pbs.twimg.com/profile_images/1408010937324482563/6Ez-JJ-k_normal.jpg', profile_link_color='1DA1F2', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, has_extended_profile=True, default_profile=True, default_profile_image=False, following=False, follow_request_sent=False, notifications=False, translator_type='none', withheld_in_countries=[]),
#  'user': User(_api=<tweepy.api.API object at 0x7f13505976a0>, _json={'id': 1397939023545503744, 'id_str': '1397939023545503744', 'name': 'Alexandre Campos', 'screen_name': 'AlexandreCmps70', 'location': 'Duas Barras, Brasil', 'description': 'O desejo cria, o pensamento atraí, a fé realiza!', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 13, 'friends_count': 128, 'listed_count': 0, 'created_at': 'Thu May 27 15:33:44 +0000 2021', 'favourites_count': 853, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 753, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1408010937324482563/6Ez-JJ-k_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1408010937324482563/6Ez-JJ-k_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, id=1397939023545503744, id_str='1397939023545503744', name='Alexandre Campos', screen_name='AlexandreCmps70', location='Duas Barras, Brasil', description='O desejo cria, o pensamento atraí, a fé realiza!', url=None, entities={'description': {'urls': []}}, protected=False, followers_count=13, friends_count=128, listed_count=0, created_at=datetime.datetime(2021, 5, 27, 15, 33, 44, tzinfo=datetime.timezone.utc), favourites_count=853, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=753, lang=None, contributors_enabled=False, is_translator=False, is_translation_enabled=False, profile_background_color='F5F8FA', profile_background_image_url=None, profile_background_image_url_https=None, profile_background_tile=False, profile_image_url='http://pbs.twimg.com/profile_images/1408010937324482563/6Ez-JJ-k_normal.jpg', profile_image_url_https='https://pbs.twimg.com/profile_images/1408010937324482563/6Ez-JJ-k_normal.jpg', profile_link_color='1DA1F2', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, has_extended_profile=True, default_profile=True, default_profile_image=False, following=False, follow_request_sent=False, notifications=False, translator_type='none', withheld_in_countries=[]),
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': False,
#  'lang': 'pt'}

# %%
# Show all attributes of the user who wrote the tweet
print(tweets[0].user)
# Out:
# User(_api=<tweepy.api.API object at 0x7f13505976a0>, _json={'id': 1397939023545503744, 'id_str': '1397939023545503744', 'name': 'Alexandre Campos', 'screen_name': 'AlexandreCmps70', 'location': 'Duas Barras, Brasil', 'description': 'O desejo cria, o pensamento atraí, a fé realiza!', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 13, 'friends_count': 128, 'listed_count': 0, 'created_at': 'Thu May 27 15:33:44 +0000 2021', 'favourites_count': 853, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 753, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1408010937324482563/6Ez-JJ-k_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1408010937324482563/6Ez-JJ-k_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, id=1397939023545503744, id_str='1397939023545503744', name='Alexandre Campos', screen_name='AlexandreCmps70', location='Duas Barras, Brasil', description='O desejo cria, o pensamento atraí, a fé realiza!', url=None, entities={'description': {'urls': []}}, protected=False, followers_count=13, friends_count=128, listed_count=0, created_at=datetime.datetime(2021, 5, 27, 15, 33, 44, tzinfo=datetime.timezone.utc), favourites_count=853, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=753, lang=None, contributors_enabled=False, is_translator=False, is_translation_enabled=False, profile_background_color='F5F8FA', profile_background_image_url=None, profile_background_image_url_https=None, profile_background_tile=False, profile_image_url='http://pbs.twimg.com/profile_images/1408010937324482563/6Ez-JJ-k_normal.jpg', profile_image_url_https='https://pbs.twimg.com/profile_images/1408010937324482563/6Ez-JJ-k_normal.jpg', profile_link_color='1DA1F2', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, has_extended_profile=True, default_profile=True, default_profile_image=False, following=False, follow_request_sent=False, notifications=False, translator_type='none', withheld_in_countries=[])

# %% [markdown]
# # 3. Saving the results

# %% [markdown]
# We have two options for saving the results.
# 1. We can select specific attributes and save them as a tsv-file.
# 2. If we do not want to decide yet which attributes we need, we can simply dump the whole JSON result to a file and process it later.
#
# **Make sure that you understand the code below. Open the result files in an editor and compare the differences.**

# %%
import json
# Collect the results
tweets_as_json =[]
tweets_as_text =[]

for tweet in tweets: 
    
    # Option 1: only keep selected attributes
    text = tweet.text.replace("\n", " ")
    keep = str(tweet.created_at) + "\t" + tweet.user.screen_name + "\t" + text
    tweets_as_text.append(keep)  
    
    # Option 2: keep everything and process later
    tweets_as_json.append(tweet._json)
    
# Write them to a file
csv_file = "../results/twitter_search_results/results_veganism.csv"
json_file = "../results/twitter_search_results/results_veganism.json"

with open(csv_file, 'w',encoding="utf-8") as outfile:
    csv_header = "Created at\tUser\tText\n"
    outfile.write(csv_header)
    outfile.write("\n".join(tweets_as_text))

with open(json_file, 'w') as outfile:
    json.dump(tweets_as_json, outfile)
